# %%
import pandas as pd
import numpy as np

data = pd.read_csv('/content/daily-website-visitors.csv')
data=data.drop(columns=['Row', 'Day','Date' ])

for i in range(1, 5):
    for j in range(len(data[data.columns[i]])):
        data[data.columns[i]][j] = float(data[data.columns[i]][j].replace(',', ''))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
import numpy as np
data= data.values
data=np.asarray(data, dtype='float32')
data=pd.DataFrame(data)

y=data[4]
y=y.values
y=y.reshape(-1, 1)
data=data.drop(columns=[4])
X=data.values

import numpy as np
X=np.concatenate((X[1:], y[0:-1]), axis=1)

# %%
pip install keras-self-attention
# Out:
# Collecting keras-self-attention
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-self-attention) (1.21.5)
# Building wheels for collected packages: keras-self-attention
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18912 sha256=ac8a2e96a0462fa2c36476c475dbaef010808da3651fb354bab1563cb1fc60da
#   Stored in directory: /root/.cache/pip/wheels/95/b1/a8/5ee00cc137940b2f6fa198212e8f45d813d0e0d9c3a04035a3
# Successfully built keras-self-attention
# Installing collected packages: keras-self-attention
# Successfully installed keras-self-attention-0.51.0

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X= sc.fit_transform(X)

# %%
pip install pyrcn
# Out:
# Collecting pyrcn
#   Downloading PyRCN-0.0.16.post1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 3.6 MB/s
# Installing collected packages: pyrcn
# Successfully installed pyrcn-0.0.16.post1

# %%
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1 = train_test_split(X, y[1:], test_size=0.2, shuffle=False, random_state=42)

# %%
x_train1.shape
# Out:
# (1732, 5)

# %%
from pyrcn.base.blocks import InputToNode
from sklearn . datasets import make_blobs
# Generate a toy dataset

# %%
input_to_node = InputToNode (10, input_activation='relu',input_scaling =1.0 , bias_scaling =0.1)


x_train= input_to_node.fit_transform (x_train1)
x_test= input_to_node.transform (x_test1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:77: FutureWarning: Pass hidden_layer_size=10 as keyword args. From version 1.1 (renaming of 0.26) passing these as positional arguments will result in an error
#   FutureWarning,

# %%
from pyrcn.base.blocks import NodeToNode
node_to_node = NodeToNode (10, reservoir_activation='relu', spectral_radius =1.0 , leakage =0.8 ,bidirectional = True )
x_train=node_to_node . fit_transform(x_train)
x_test= node_to_node.transform (x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:77: FutureWarning: Pass hidden_layer_size=10 as keyword args. From version 1.1 (renaming of 0.26) passing these as positional arguments will result in an error
#   FutureWarning,

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

x_train1 = x_train1.reshape((x_train1.shape[0], x_train1.shape[1], 1))
x_test1 = x_test1.reshape((x_test1.shape[0], x_test1.shape[1], 1))

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
from keras_self_attention import SeqSelfAttention
def build_model(
    input_shapey,
    input_shapez,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputsy = keras.Input(shape=input_shapey)
    inputsz = keras.Input(shape=input_shapez)
    y = inputsy
    z= inputsz

    #z=layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(z)

    #y=layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(y)

    z=SeqSelfAttention()(z)

    #y=SeqSelfAttention()(y)



    x=layers.Concatenate(axis=1)([y, z])
    #x=layers.Add()([inputsy, inputsz])

    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model([inputsy,inputsz], outputs)

# %%
input_shapey = x_train1.shape[1:]
input_shapez = x_train.shape[1:]

model = build_model(
    input_shapey,
    input_shapez,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="mean_absolute_error",
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    metrics=["mean_absolute_error"],
)
'''
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["sparse_categorical_accuracy"],
)
'''
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 20, 1)]      0           []
#
#  input_7 (InputLayer)           [(None, 5, 1)]       0           []
#
#  seq_self_attention_5 (SeqSelfA  (None, 20, 1)       129         ['input_8[0][0]']
#  ttention)
#
#  concatenate_3 (Concatenate)    (None, 25, 1)        0           ['input_7[0][0]',
#                                                                   'seq_self_attention_5[0][0]']
#
#  layer_normalization_24 (LayerN  (None, 25, 1)       2           ['concatenate_3[0][0]']
#  ormalization)
#
#  multi_head_attention_12 (Multi  (None, 25, 1)       7169        ['layer_normalization_24[0][0]',
#  HeadAttention)                                                   'layer_normalization_24[0][0]']
#
#  dropout_27 (Dropout)           (None, 25, 1)        0           ['multi_head_attention_12[0][0]']
#
#  tf.__operators__.add_24 (TFOpL  (None, 25, 1)       0           ['dropout_27[0][0]',
#  ambda)                                                           'concatenate_3[0][0]']
#
#  layer_normalization_25 (LayerN  (None, 25, 1)       2           ['tf.__operators__.add_24[0][0]']
#  ormalization)
#
#  conv1d_24 (Conv1D)             (None, 25, 4)        8           ['layer_normalization_25[0][0]']
#
#  dropout_28 (Dropout)           (None, 25, 4)        0           ['conv1d_24[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 25, 1)        5           ['dropout_28[0][0]']
#
#  tf.__operators__.add_25 (TFOpL  (None, 25, 1)       0           ['conv1d_25[0][0]',
#  ambda)                                                           'tf.__operators__.add_24[0][0]']
#
#  layer_normalization_26 (LayerN  (None, 25, 1)       2           ['tf.__operators__.add_25[0][0]']
#  ormalization)
#
#  multi_head_attention_13 (Multi  (None, 25, 1)       7169        ['layer_normalization_26[0][0]',
#  HeadAttention)                                                   'layer_normalization_26[0][0]']
#
#  dropout_29 (Dropout)           (None, 25, 1)        0           ['multi_head_attention_13[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None, 25, 1)       0           ['dropout_29[0][0]',
#  ambda)                                                           'tf.__operators__.add_25[0][0]']
#
#  layer_normalization_27 (LayerN  (None, 25, 1)       2           ['tf.__operators__.add_26[0][0]']
#  ormalization)
#
#  conv1d_26 (Conv1D)             (None, 25, 4)        8           ['layer_normalization_27[0][0]']
#
#  dropout_30 (Dropout)           (None, 25, 4)        0           ['conv1d_26[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 25, 1)        5           ['dropout_30[0][0]']
#
#  tf.__operators__.add_27 (TFOpL  (None, 25, 1)       0           ['conv1d_27[0][0]',
#  ambda)                                                           'tf.__operators__.add_26[0][0]']
#
#  layer_normalization_28 (LayerN  (None, 25, 1)       2           ['tf.__operators__.add_27[0][0]']
#  ormalization)
#
#  multi_head_attention_14 (Multi  (None, 25, 1)       7169        ['layer_normalization_28[0][0]',
#  HeadAttention)                                                   'layer_normalization_28[0][0]']
#
#  dropout_31 (Dropout)           (None, 25, 1)        0           ['multi_head_attention_14[0][0]']
#
#  tf.__operators__.add_28 (TFOpL  (None, 25, 1)       0           ['dropout_31[0][0]',
#  ambda)                                                           'tf.__operators__.add_27[0][0]']
#
#  layer_normalization_29 (LayerN  (None, 25, 1)       2           ['tf.__operators__.add_28[0][0]']
#  ormalization)
#
#  conv1d_28 (Conv1D)             (None, 25, 4)        8           ['layer_normalization_29[0][0]']
#
#  dropout_32 (Dropout)           (None, 25, 4)        0           ['conv1d_28[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 25, 1)        5           ['dropout_32[0][0]']
#
#  tf.__operators__.add_29 (TFOpL  (None, 25, 1)       0           ['conv1d_29[0][0]',
#  ambda)                                                           'tf.__operators__.add_28[0][0]']
#
#  layer_normalization_30 (LayerN  (None, 25, 1)       2           ['tf.__operators__.add_29[0][0]']
#  ormalization)
#
#  multi_head_attention_15 (Multi  (None, 25, 1)       7169        ['layer_normalization_30[0][0]',
#  HeadAttention)                                                   'layer_normalization_30[0][0]']
#
#  dropout_33 (Dropout)           (None, 25, 1)        0           ['multi_head_attention_15[0][0]']
#
#  tf.__operators__.add_30 (TFOpL  (None, 25, 1)       0           ['dropout_33[0][0]',
#  ambda)                                                           'tf.__operators__.add_29[0][0]']
#
#  layer_normalization_31 (LayerN  (None, 25, 1)       2           ['tf.__operators__.add_30[0][0]']
#  ormalization)
#
#  conv1d_30 (Conv1D)             (None, 25, 4)        8           ['layer_normalization_31[0][0]']
#
#  dropout_34 (Dropout)           (None, 25, 4)        0           ['conv1d_30[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 25, 1)        5           ['dropout_34[0][0]']
#
#  tf.__operators__.add_31 (TFOpL  (None, 25, 1)       0           ['conv1d_31[0][0]',
#  ambda)                                                           'tf.__operators__.add_30[0][0]']
#
#  global_average_pooling1d_3 (Gl  (None, 25)          0           ['tf.__operators__.add_31[0][0]']
#  obalAveragePooling1D)
#
#  dense_6 (Dense)                (None, 128)          3328        ['global_average_pooling1d_3[0][0
#                                                                  ]']
#
#  dropout_35 (Dropout)           (None, 128)          0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 1)            129         ['dropout_35[0][0]']
#
# ==================================================================================================
# Total params: 32,330
# Trainable params: 32,330
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(
    loss="mean_absolute_error",
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    metrics=["mean_absolute_error"],
)
callbacks = [keras.callbacks.EarlyStopping(patience=250, restore_best_weights=True)]

history=model.fit(
    [x_train1,x_train],
    y_train1,
    validation_data=([x_test1, x_test], y_test1),
    epochs=2000,
    batch_size=64,
    callbacks=callbacks,
)
# Out:
# Epoch 1/2000
# 28/28 [==============================] - 5s 38ms/step - loss: 66.8300 - mean_absolute_error: 66.8300 - val_loss: 51.5919 - val_mean_absolute_error: 51.5919
# Epoch 2/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 52.9529 - mean_absolute_error: 52.9529 - val_loss: 11.3787 - val_mean_absolute_error: 11.3787
# Epoch 3/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.1210 - mean_absolute_error: 47.1210 - val_loss: 6.8551 - val_mean_absolute_error: 6.8551
# Epoch 4/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.9875 - mean_absolute_error: 49.9875 - val_loss: 24.7197 - val_mean_absolute_error: 24.7197
# Epoch 5/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.5621 - mean_absolute_error: 49.5621 - val_loss: 15.6523 - val_mean_absolute_error: 15.6523
# Epoch 6/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 51.3142 - mean_absolute_error: 51.3142 - val_loss: 54.2404 - val_mean_absolute_error: 54.2404
# Epoch 7/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 51.1096 - mean_absolute_error: 51.1096 - val_loss: 3.9213 - val_mean_absolute_error: 3.9213
# Epoch 8/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.8393 - mean_absolute_error: 47.8393 - val_loss: 12.3851 - val_mean_absolute_error: 12.3851
# Epoch 9/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 47.9273 - mean_absolute_error: 47.9273 - val_loss: 42.5903 - val_mean_absolute_error: 42.5903
# Epoch 10/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 51.6950 - mean_absolute_error: 51.6950 - val_loss: 25.5007 - val_mean_absolute_error: 25.5007
# Epoch 11/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.7815 - mean_absolute_error: 49.7815 - val_loss: 21.5484 - val_mean_absolute_error: 21.5484
# Epoch 12/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.7610 - mean_absolute_error: 49.7610 - val_loss: 20.8378 - val_mean_absolute_error: 20.8378
# Epoch 13/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 51.3207 - mean_absolute_error: 51.3207 - val_loss: 11.3347 - val_mean_absolute_error: 11.3347
# Epoch 14/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 51.0558 - mean_absolute_error: 51.0558 - val_loss: 16.1923 - val_mean_absolute_error: 16.1923
# Epoch 15/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 56.7901 - mean_absolute_error: 56.7901 - val_loss: 79.7283 - val_mean_absolute_error: 79.7283
# Epoch 16/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 60.5904 - mean_absolute_error: 60.5904 - val_loss: 13.3292 - val_mean_absolute_error: 13.3292
# Epoch 17/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.2019 - mean_absolute_error: 48.2019 - val_loss: 46.7666 - val_mean_absolute_error: 46.7666
# Epoch 18/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 52.2496 - mean_absolute_error: 52.2496 - val_loss: 8.9118 - val_mean_absolute_error: 8.9118
# Epoch 19/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.2182 - mean_absolute_error: 48.2182 - val_loss: 32.9479 - val_mean_absolute_error: 32.9479
# Epoch 20/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 54.2482 - mean_absolute_error: 54.2482 - val_loss: 37.9727 - val_mean_absolute_error: 37.9727
# Epoch 21/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 47.9127 - mean_absolute_error: 47.9127 - val_loss: 42.4711 - val_mean_absolute_error: 42.4711
# Epoch 22/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.4479 - mean_absolute_error: 50.4479 - val_loss: 12.3704 - val_mean_absolute_error: 12.3704
# Epoch 23/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 50.0664 - mean_absolute_error: 50.0664 - val_loss: 9.5392 - val_mean_absolute_error: 9.5392
# Epoch 24/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.4164 - mean_absolute_error: 50.4164 - val_loss: 30.5554 - val_mean_absolute_error: 30.5554
# Epoch 25/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 49.6958 - mean_absolute_error: 49.6958 - val_loss: 3.7930 - val_mean_absolute_error: 3.7930
# Epoch 26/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.4058 - mean_absolute_error: 46.4058 - val_loss: 5.6518 - val_mean_absolute_error: 5.6518
# Epoch 27/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 45.3738 - mean_absolute_error: 45.3738 - val_loss: 21.1197 - val_mean_absolute_error: 21.1197
# Epoch 28/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.6754 - mean_absolute_error: 47.6754 - val_loss: 4.3575 - val_mean_absolute_error: 4.3575
# Epoch 29/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.0464 - mean_absolute_error: 48.0464 - val_loss: 5.8970 - val_mean_absolute_error: 5.8970
# Epoch 30/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 48.4165 - mean_absolute_error: 48.4165 - val_loss: 76.6439 - val_mean_absolute_error: 76.6439
# Epoch 31/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 56.7115 - mean_absolute_error: 56.7115 - val_loss: 85.1355 - val_mean_absolute_error: 85.1355
# Epoch 32/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 57.0400 - mean_absolute_error: 57.0400 - val_loss: 54.5053 - val_mean_absolute_error: 54.5053
# Epoch 33/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 54.5852 - mean_absolute_error: 54.5852 - val_loss: 14.1256 - val_mean_absolute_error: 14.1256
# Epoch 34/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.9400 - mean_absolute_error: 48.9400 - val_loss: 21.5755 - val_mean_absolute_error: 21.5755
# Epoch 35/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.6782 - mean_absolute_error: 50.6782 - val_loss: 3.0769 - val_mean_absolute_error: 3.0769
# Epoch 36/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.8407 - mean_absolute_error: 49.8407 - val_loss: 10.1591 - val_mean_absolute_error: 10.1591
# Epoch 37/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 48.7413 - mean_absolute_error: 48.7413 - val_loss: 7.2641 - val_mean_absolute_error: 7.2641
# Epoch 38/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.8493 - mean_absolute_error: 50.8493 - val_loss: 7.4122 - val_mean_absolute_error: 7.4122
# Epoch 39/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 51.0837 - mean_absolute_error: 51.0837 - val_loss: 22.3904 - val_mean_absolute_error: 22.3904
# Epoch 40/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 50.0493 - mean_absolute_error: 50.0493 - val_loss: 64.6272 - val_mean_absolute_error: 64.6272
# Epoch 41/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 50.9725 - mean_absolute_error: 50.9725 - val_loss: 14.5948 - val_mean_absolute_error: 14.5948
# Epoch 42/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.0426 - mean_absolute_error: 47.0426 - val_loss: 2.2875 - val_mean_absolute_error: 2.2875
# Epoch 43/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.9710 - mean_absolute_error: 48.9710 - val_loss: 10.4103 - val_mean_absolute_error: 10.4103
# Epoch 44/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 51.7929 - mean_absolute_error: 51.7929 - val_loss: 2.3667 - val_mean_absolute_error: 2.3667
# Epoch 45/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.0937 - mean_absolute_error: 48.0937 - val_loss: 9.4508 - val_mean_absolute_error: 9.4508
# Epoch 46/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.4157 - mean_absolute_error: 47.4157 - val_loss: 1.8968 - val_mean_absolute_error: 1.8968
# Epoch 47/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.1385 - mean_absolute_error: 50.1385 - val_loss: 6.1233 - val_mean_absolute_error: 6.1233
# Epoch 48/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.2109 - mean_absolute_error: 48.2109 - val_loss: 27.6885 - val_mean_absolute_error: 27.6885
# Epoch 49/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.3218 - mean_absolute_error: 49.3218 - val_loss: 43.4416 - val_mean_absolute_error: 43.4416
# Epoch 50/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 63.8597 - mean_absolute_error: 63.8597 - val_loss: 15.8405 - val_mean_absolute_error: 15.8405
# Epoch 51/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.7902 - mean_absolute_error: 50.7902 - val_loss: 69.6712 - val_mean_absolute_error: 69.6712
# Epoch 52/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 59.9457 - mean_absolute_error: 59.9457 - val_loss: 17.5019 - val_mean_absolute_error: 17.5019
# Epoch 53/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 54.9843 - mean_absolute_error: 54.9843 - val_loss: 5.3909 - val_mean_absolute_error: 5.3909
# Epoch 54/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.7399 - mean_absolute_error: 48.7399 - val_loss: 10.0173 - val_mean_absolute_error: 10.0173
# Epoch 55/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.2249 - mean_absolute_error: 48.2249 - val_loss: 24.1009 - val_mean_absolute_error: 24.1009
# Epoch 56/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 51.0415 - mean_absolute_error: 51.0415 - val_loss: 24.4577 - val_mean_absolute_error: 24.4577
# Epoch 57/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 52.0323 - mean_absolute_error: 52.0323 - val_loss: 16.6746 - val_mean_absolute_error: 16.6746
# Epoch 58/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.4105 - mean_absolute_error: 47.4105 - val_loss: 17.7247 - val_mean_absolute_error: 17.7247
# Epoch 59/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.1353 - mean_absolute_error: 48.1353 - val_loss: 6.9682 - val_mean_absolute_error: 6.9682
# Epoch 60/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 46.1118 - mean_absolute_error: 46.1118 - val_loss: 18.3381 - val_mean_absolute_error: 18.3381
# Epoch 61/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.4789 - mean_absolute_error: 48.4789 - val_loss: 8.7332 - val_mean_absolute_error: 8.7332
# Epoch 62/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.2167 - mean_absolute_error: 48.2167 - val_loss: 10.3772 - val_mean_absolute_error: 10.3772
# Epoch 63/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.8365 - mean_absolute_error: 49.8365 - val_loss: 7.6715 - val_mean_absolute_error: 7.6715
# Epoch 64/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 52.6547 - mean_absolute_error: 52.6547 - val_loss: 30.2808 - val_mean_absolute_error: 30.2808
# Epoch 65/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.6006 - mean_absolute_error: 48.6006 - val_loss: 46.5525 - val_mean_absolute_error: 46.5525
# Epoch 66/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 52.9898 - mean_absolute_error: 52.9898 - val_loss: 23.1550 - val_mean_absolute_error: 23.1550
# Epoch 67/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 47.8965 - mean_absolute_error: 47.8965 - val_loss: 7.9595 - val_mean_absolute_error: 7.9595
# Epoch 68/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 48.8467 - mean_absolute_error: 48.8467 - val_loss: 45.4868 - val_mean_absolute_error: 45.4868
# Epoch 69/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 50.5163 - mean_absolute_error: 50.5163 - val_loss: 46.3191 - val_mean_absolute_error: 46.3191
# Epoch 70/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 54.3994 - mean_absolute_error: 54.3994 - val_loss: 28.0293 - val_mean_absolute_error: 28.0293
# Epoch 71/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.0958 - mean_absolute_error: 50.0958 - val_loss: 27.8212 - val_mean_absolute_error: 27.8212
# Epoch 72/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.3512 - mean_absolute_error: 47.3512 - val_loss: 18.6969 - val_mean_absolute_error: 18.6969
# Epoch 73/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.1748 - mean_absolute_error: 49.1748 - val_loss: 11.1834 - val_mean_absolute_error: 11.1834
# Epoch 74/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 52.8683 - mean_absolute_error: 52.8683 - val_loss: 18.4288 - val_mean_absolute_error: 18.4288
# Epoch 75/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 49.3760 - mean_absolute_error: 49.3760 - val_loss: 56.3590 - val_mean_absolute_error: 56.3590
# Epoch 76/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 61.7669 - mean_absolute_error: 61.7669 - val_loss: 28.1372 - val_mean_absolute_error: 28.1372
# Epoch 77/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.6904 - mean_absolute_error: 49.6904 - val_loss: 4.0806 - val_mean_absolute_error: 4.0806
# Epoch 78/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 49.7447 - mean_absolute_error: 49.7447 - val_loss: 35.6134 - val_mean_absolute_error: 35.6134
# Epoch 79/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 52.1785 - mean_absolute_error: 52.1785 - val_loss: 30.8734 - val_mean_absolute_error: 30.8734
# Epoch 80/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 52.6795 - mean_absolute_error: 52.6795 - val_loss: 2.7559 - val_mean_absolute_error: 2.7559
# Epoch 81/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.0388 - mean_absolute_error: 49.0388 - val_loss: 52.6830 - val_mean_absolute_error: 52.6830
# Epoch 82/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.8254 - mean_absolute_error: 50.8254 - val_loss: 38.2788 - val_mean_absolute_error: 38.2788
# Epoch 83/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 55.1836 - mean_absolute_error: 55.1836 - val_loss: 6.1180 - val_mean_absolute_error: 6.1180
# Epoch 84/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.9247 - mean_absolute_error: 49.9247 - val_loss: 55.6521 - val_mean_absolute_error: 55.6521
# Epoch 85/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 56.7560 - mean_absolute_error: 56.7560 - val_loss: 8.2977 - val_mean_absolute_error: 8.2977
# Epoch 86/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.6385 - mean_absolute_error: 48.6385 - val_loss: 15.4531 - val_mean_absolute_error: 15.4531
# Epoch 87/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.4821 - mean_absolute_error: 47.4821 - val_loss: 46.5852 - val_mean_absolute_error: 46.5852
# Epoch 88/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 53.2554 - mean_absolute_error: 53.2554 - val_loss: 21.0607 - val_mean_absolute_error: 21.0607
# Epoch 89/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.8452 - mean_absolute_error: 50.8452 - val_loss: 28.2012 - val_mean_absolute_error: 28.2012
# Epoch 90/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.6236 - mean_absolute_error: 47.6236 - val_loss: 36.2912 - val_mean_absolute_error: 36.2912
# Epoch 91/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 50.9571 - mean_absolute_error: 50.9571 - val_loss: 6.1113 - val_mean_absolute_error: 6.1113
# Epoch 92/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.4544 - mean_absolute_error: 52.4544 - val_loss: 7.8957 - val_mean_absolute_error: 7.8957
# Epoch 93/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 51.1499 - mean_absolute_error: 51.1499 - val_loss: 9.0800 - val_mean_absolute_error: 9.0800
# Epoch 94/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.3486 - mean_absolute_error: 46.3486 - val_loss: 15.6389 - val_mean_absolute_error: 15.6389
# Epoch 95/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.3086 - mean_absolute_error: 49.3086 - val_loss: 41.8876 - val_mean_absolute_error: 41.8876
# Epoch 96/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.2387 - mean_absolute_error: 48.2387 - val_loss: 12.7292 - val_mean_absolute_error: 12.7292
# Epoch 97/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 47.0815 - mean_absolute_error: 47.0815 - val_loss: 40.0900 - val_mean_absolute_error: 40.0900
# Epoch 98/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 49.8562 - mean_absolute_error: 49.8562 - val_loss: 35.3609 - val_mean_absolute_error: 35.3609
# Epoch 99/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 54.8216 - mean_absolute_error: 54.8216 - val_loss: 58.0742 - val_mean_absolute_error: 58.0742
# Epoch 100/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.4178 - mean_absolute_error: 50.4178 - val_loss: 45.4435 - val_mean_absolute_error: 45.4435
# Epoch 101/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 50.5861 - mean_absolute_error: 50.5861 - val_loss: 29.0327 - val_mean_absolute_error: 29.0327
# Epoch 102/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.5293 - mean_absolute_error: 48.5293 - val_loss: 21.7570 - val_mean_absolute_error: 21.7570
# Epoch 103/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.6642 - mean_absolute_error: 48.6642 - val_loss: 12.8027 - val_mean_absolute_error: 12.8027
# Epoch 104/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.0563 - mean_absolute_error: 48.0563 - val_loss: 16.3755 - val_mean_absolute_error: 16.3755
# Epoch 105/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 48.4083 - mean_absolute_error: 48.4083 - val_loss: 14.6341 - val_mean_absolute_error: 14.6341
# Epoch 106/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.1280 - mean_absolute_error: 48.1280 - val_loss: 3.1434 - val_mean_absolute_error: 3.1434
# Epoch 107/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 45.2660 - mean_absolute_error: 45.2660 - val_loss: 3.3478 - val_mean_absolute_error: 3.3478
# Epoch 108/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.4299 - mean_absolute_error: 49.4299 - val_loss: 2.3223 - val_mean_absolute_error: 2.3223
# Epoch 109/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.0133 - mean_absolute_error: 48.0133 - val_loss: 17.0916 - val_mean_absolute_error: 17.0916
# Epoch 110/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.7544 - mean_absolute_error: 47.7544 - val_loss: 6.8191 - val_mean_absolute_error: 6.8191
# Epoch 111/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.2201 - mean_absolute_error: 48.2201 - val_loss: 2.9601 - val_mean_absolute_error: 2.9601
# Epoch 112/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.1924 - mean_absolute_error: 48.1924 - val_loss: 6.6149 - val_mean_absolute_error: 6.6149
# Epoch 113/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.8434 - mean_absolute_error: 48.8434 - val_loss: 70.6532 - val_mean_absolute_error: 70.6532
# Epoch 114/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 60.6075 - mean_absolute_error: 60.6075 - val_loss: 44.0207 - val_mean_absolute_error: 44.0207
# Epoch 115/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 54.4981 - mean_absolute_error: 54.4981 - val_loss: 2.4708 - val_mean_absolute_error: 2.4708
# Epoch 116/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.3737 - mean_absolute_error: 48.3737 - val_loss: 36.7094 - val_mean_absolute_error: 36.7094
# Epoch 117/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 52.8319 - mean_absolute_error: 52.8319 - val_loss: 3.4375 - val_mean_absolute_error: 3.4375
# Epoch 118/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.2708 - mean_absolute_error: 46.2708 - val_loss: 25.0101 - val_mean_absolute_error: 25.0101
# Epoch 119/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 52.6749 - mean_absolute_error: 52.6749 - val_loss: 25.4721 - val_mean_absolute_error: 25.4721
# Epoch 120/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.3394 - mean_absolute_error: 47.3394 - val_loss: 33.0237 - val_mean_absolute_error: 33.0237
# Epoch 121/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.5653 - mean_absolute_error: 48.5653 - val_loss: 30.3828 - val_mean_absolute_error: 30.3828
# Epoch 122/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.0189 - mean_absolute_error: 48.0189 - val_loss: 44.7375 - val_mean_absolute_error: 44.7375
# Epoch 123/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.3363 - mean_absolute_error: 52.3363 - val_loss: 18.0086 - val_mean_absolute_error: 18.0086
# Epoch 124/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.7327 - mean_absolute_error: 48.7327 - val_loss: 10.1128 - val_mean_absolute_error: 10.1128
# Epoch 125/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 45.8972 - mean_absolute_error: 45.8972 - val_loss: 17.9262 - val_mean_absolute_error: 17.9262
# Epoch 126/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.1697 - mean_absolute_error: 48.1697 - val_loss: 28.8604 - val_mean_absolute_error: 28.8604
# Epoch 127/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.5322 - mean_absolute_error: 49.5322 - val_loss: 16.0303 - val_mean_absolute_error: 16.0303
# Epoch 128/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 49.7147 - mean_absolute_error: 49.7147 - val_loss: 9.5572 - val_mean_absolute_error: 9.5572
# Epoch 129/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 54.0902 - mean_absolute_error: 54.0902 - val_loss: 24.4696 - val_mean_absolute_error: 24.4696
# Epoch 130/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 51.8765 - mean_absolute_error: 51.8765 - val_loss: 37.6611 - val_mean_absolute_error: 37.6611
# Epoch 131/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 51.9639 - mean_absolute_error: 51.9639 - val_loss: 31.8233 - val_mean_absolute_error: 31.8233
# Epoch 132/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 51.1046 - mean_absolute_error: 51.1046 - val_loss: 18.2592 - val_mean_absolute_error: 18.2592
# Epoch 133/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.1518 - mean_absolute_error: 47.1518 - val_loss: 17.6025 - val_mean_absolute_error: 17.6025
# Epoch 134/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.2823 - mean_absolute_error: 46.2823 - val_loss: 18.1896 - val_mean_absolute_error: 18.1896
# Epoch 135/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 56.4233 - mean_absolute_error: 56.4233 - val_loss: 41.0743 - val_mean_absolute_error: 41.0743
# Epoch 136/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.5580 - mean_absolute_error: 48.5580 - val_loss: 31.8142 - val_mean_absolute_error: 31.8142
# Epoch 137/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.1299 - mean_absolute_error: 50.1299 - val_loss: 26.2806 - val_mean_absolute_error: 26.2806
# Epoch 138/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.4023 - mean_absolute_error: 50.4023 - val_loss: 48.7558 - val_mean_absolute_error: 48.7558
# Epoch 139/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.4192 - mean_absolute_error: 52.4192 - val_loss: 11.4037 - val_mean_absolute_error: 11.4037
# Epoch 140/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 56.5723 - mean_absolute_error: 56.5723 - val_loss: 5.2593 - val_mean_absolute_error: 5.2593
# Epoch 141/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.1790 - mean_absolute_error: 47.1790 - val_loss: 9.4777 - val_mean_absolute_error: 9.4777
# Epoch 142/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.3536 - mean_absolute_error: 48.3536 - val_loss: 16.1384 - val_mean_absolute_error: 16.1384
# Epoch 143/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.3253 - mean_absolute_error: 46.3253 - val_loss: 17.9016 - val_mean_absolute_error: 17.9016
# Epoch 144/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 48.8376 - mean_absolute_error: 48.8376 - val_loss: 40.2167 - val_mean_absolute_error: 40.2167
# Epoch 145/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.6670 - mean_absolute_error: 52.6670 - val_loss: 22.6511 - val_mean_absolute_error: 22.6511
# Epoch 146/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 46.4155 - mean_absolute_error: 46.4155 - val_loss: 10.8023 - val_mean_absolute_error: 10.8023
# Epoch 147/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.7244 - mean_absolute_error: 47.7244 - val_loss: 54.2055 - val_mean_absolute_error: 54.2055
# Epoch 148/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 55.7530 - mean_absolute_error: 55.7530 - val_loss: 4.1623 - val_mean_absolute_error: 4.1623
# Epoch 149/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 45.0447 - mean_absolute_error: 45.0447 - val_loss: 30.3051 - val_mean_absolute_error: 30.3051
# Epoch 150/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 46.7780 - mean_absolute_error: 46.7780 - val_loss: 2.7108 - val_mean_absolute_error: 2.7108
# Epoch 151/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.1122 - mean_absolute_error: 52.1122 - val_loss: 10.2310 - val_mean_absolute_error: 10.2310
# Epoch 152/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 48.8631 - mean_absolute_error: 48.8631 - val_loss: 6.6898 - val_mean_absolute_error: 6.6898
# Epoch 153/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.5203 - mean_absolute_error: 47.5203 - val_loss: 60.3119 - val_mean_absolute_error: 60.3119
# Epoch 154/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.6931 - mean_absolute_error: 48.6931 - val_loss: 33.1482 - val_mean_absolute_error: 33.1482
# Epoch 155/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 46.8528 - mean_absolute_error: 46.8528 - val_loss: 14.9466 - val_mean_absolute_error: 14.9466
# Epoch 156/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 47.6770 - mean_absolute_error: 47.6770 - val_loss: 8.4072 - val_mean_absolute_error: 8.4072
# Epoch 157/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.5503 - mean_absolute_error: 46.5503 - val_loss: 19.2322 - val_mean_absolute_error: 19.2322
# Epoch 158/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.9030 - mean_absolute_error: 47.9030 - val_loss: 17.1428 - val_mean_absolute_error: 17.1428
# Epoch 159/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.4883 - mean_absolute_error: 50.4883 - val_loss: 9.1700 - val_mean_absolute_error: 9.1700
# Epoch 160/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.6770 - mean_absolute_error: 48.6770 - val_loss: 19.5279 - val_mean_absolute_error: 19.5279
# Epoch 161/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 54.6427 - mean_absolute_error: 54.6427 - val_loss: 42.9431 - val_mean_absolute_error: 42.9431
# Epoch 162/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 49.6282 - mean_absolute_error: 49.6282 - val_loss: 15.5862 - val_mean_absolute_error: 15.5862
# Epoch 163/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.6751 - mean_absolute_error: 50.6751 - val_loss: 9.6383 - val_mean_absolute_error: 9.6383
# Epoch 164/2000
# 28/28 [==============================] - 1s 28ms/step - loss: 46.4652 - mean_absolute_error: 46.4652 - val_loss: 37.5529 - val_mean_absolute_error: 37.5529
# Epoch 165/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.1922 - mean_absolute_error: 48.1922 - val_loss: 2.4056 - val_mean_absolute_error: 2.4056
# Epoch 166/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 46.8797 - mean_absolute_error: 46.8797 - val_loss: 9.3954 - val_mean_absolute_error: 9.3954
# Epoch 167/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 46.4925 - mean_absolute_error: 46.4925 - val_loss: 3.9897 - val_mean_absolute_error: 3.9897
# Epoch 168/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.0447 - mean_absolute_error: 52.0447 - val_loss: 34.7036 - val_mean_absolute_error: 34.7036
# Epoch 169/2000
# 28/28 [==============================] - 0s 17ms/step - loss: 51.3888 - mean_absolute_error: 51.3888 - val_loss: 16.7485 - val_mean_absolute_error: 16.7485
# Epoch 170/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 54.9050 - mean_absolute_error: 54.9050 - val_loss: 45.8114 - val_mean_absolute_error: 45.8114
# Epoch 171/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 47.4072 - mean_absolute_error: 47.4072 - val_loss: 7.0163 - val_mean_absolute_error: 7.0163
# Epoch 172/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.1296 - mean_absolute_error: 50.1296 - val_loss: 18.6708 - val_mean_absolute_error: 18.6708
# Epoch 173/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.3944 - mean_absolute_error: 49.3944 - val_loss: 4.6524 - val_mean_absolute_error: 4.6524
# Epoch 174/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.6682 - mean_absolute_error: 48.6682 - val_loss: 25.3847 - val_mean_absolute_error: 25.3847
# Epoch 175/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 52.4872 - mean_absolute_error: 52.4872 - val_loss: 13.7472 - val_mean_absolute_error: 13.7472
# Epoch 176/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.3919 - mean_absolute_error: 50.3919 - val_loss: 19.7544 - val_mean_absolute_error: 19.7544
# Epoch 177/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.1602 - mean_absolute_error: 47.1602 - val_loss: 45.2913 - val_mean_absolute_error: 45.2913
# Epoch 178/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 57.9363 - mean_absolute_error: 57.9363 - val_loss: 36.2183 - val_mean_absolute_error: 36.2183
# Epoch 179/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 61.1896 - mean_absolute_error: 61.1896 - val_loss: 17.9731 - val_mean_absolute_error: 17.9731
# Epoch 180/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.2277 - mean_absolute_error: 47.2277 - val_loss: 2.5197 - val_mean_absolute_error: 2.5197
# Epoch 181/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.1876 - mean_absolute_error: 49.1876 - val_loss: 72.1319 - val_mean_absolute_error: 72.1319
# Epoch 182/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 55.6380 - mean_absolute_error: 55.6380 - val_loss: 8.2932 - val_mean_absolute_error: 8.2932
# Epoch 183/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.7481 - mean_absolute_error: 49.7481 - val_loss: 2.3148 - val_mean_absolute_error: 2.3148
# Epoch 184/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.7526 - mean_absolute_error: 50.7526 - val_loss: 32.6774 - val_mean_absolute_error: 32.6774
# Epoch 185/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 47.5265 - mean_absolute_error: 47.5265 - val_loss: 20.9866 - val_mean_absolute_error: 20.9866
# Epoch 186/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.7245 - mean_absolute_error: 49.7245 - val_loss: 11.5050 - val_mean_absolute_error: 11.5050
# Epoch 187/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.5888 - mean_absolute_error: 47.5888 - val_loss: 3.9332 - val_mean_absolute_error: 3.9332
# Epoch 188/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.9451 - mean_absolute_error: 46.9451 - val_loss: 14.5045 - val_mean_absolute_error: 14.5045
# Epoch 189/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.8493 - mean_absolute_error: 47.8493 - val_loss: 17.5438 - val_mean_absolute_error: 17.5438
# Epoch 190/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.8978 - mean_absolute_error: 48.8978 - val_loss: 25.5235 - val_mean_absolute_error: 25.5235
# Epoch 191/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 53.5496 - mean_absolute_error: 53.5496 - val_loss: 6.8156 - val_mean_absolute_error: 6.8156
# Epoch 192/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 57.2289 - mean_absolute_error: 57.2289 - val_loss: 48.0645 - val_mean_absolute_error: 48.0645
# Epoch 193/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 50.4704 - mean_absolute_error: 50.4704 - val_loss: 25.1820 - val_mean_absolute_error: 25.1820
# Epoch 194/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 44.6794 - mean_absolute_error: 44.6794 - val_loss: 43.6158 - val_mean_absolute_error: 43.6158
# Epoch 195/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.4241 - mean_absolute_error: 52.4241 - val_loss: 17.4390 - val_mean_absolute_error: 17.4390
# Epoch 196/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.2642 - mean_absolute_error: 49.2642 - val_loss: 80.7060 - val_mean_absolute_error: 80.7060
# Epoch 197/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 57.1897 - mean_absolute_error: 57.1897 - val_loss: 4.8689 - val_mean_absolute_error: 4.8689
# Epoch 198/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.2539 - mean_absolute_error: 47.2539 - val_loss: 24.5658 - val_mean_absolute_error: 24.5658
# Epoch 199/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.3359 - mean_absolute_error: 47.3359 - val_loss: 2.0979 - val_mean_absolute_error: 2.0979
# Epoch 200/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.4750 - mean_absolute_error: 46.4750 - val_loss: 10.7627 - val_mean_absolute_error: 10.7627
# Epoch 201/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 45.5306 - mean_absolute_error: 45.5306 - val_loss: 7.1448 - val_mean_absolute_error: 7.1448
# Epoch 202/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 45.5712 - mean_absolute_error: 45.5712 - val_loss: 14.1156 - val_mean_absolute_error: 14.1156
# Epoch 203/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.7259 - mean_absolute_error: 46.7259 - val_loss: 31.5489 - val_mean_absolute_error: 31.5489
# Epoch 204/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 46.5884 - mean_absolute_error: 46.5884 - val_loss: 41.9391 - val_mean_absolute_error: 41.9391
# Epoch 205/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 46.8168 - mean_absolute_error: 46.8168 - val_loss: 17.7773 - val_mean_absolute_error: 17.7773
# Epoch 206/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 49.0713 - mean_absolute_error: 49.0713 - val_loss: 8.0478 - val_mean_absolute_error: 8.0478
# Epoch 207/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.9669 - mean_absolute_error: 46.9669 - val_loss: 33.1717 - val_mean_absolute_error: 33.1717
# Epoch 208/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.7566 - mean_absolute_error: 50.7566 - val_loss: 14.3913 - val_mean_absolute_error: 14.3913
# Epoch 209/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.5038 - mean_absolute_error: 48.5038 - val_loss: 31.2677 - val_mean_absolute_error: 31.2677
# Epoch 210/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 54.6846 - mean_absolute_error: 54.6846 - val_loss: 6.1257 - val_mean_absolute_error: 6.1257
# Epoch 211/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 46.5194 - mean_absolute_error: 46.5194 - val_loss: 8.3670 - val_mean_absolute_error: 8.3670
# Epoch 212/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.4310 - mean_absolute_error: 48.4310 - val_loss: 14.3135 - val_mean_absolute_error: 14.3135
# Epoch 213/2000
# 28/28 [==============================] - 0s 18ms/step - loss: 47.6975 - mean_absolute_error: 47.6975 - val_loss: 3.8503 - val_mean_absolute_error: 3.8503
# Epoch 214/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 44.2153 - mean_absolute_error: 44.2153 - val_loss: 34.3919 - val_mean_absolute_error: 34.3919
# Epoch 215/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 54.3842 - mean_absolute_error: 54.3842 - val_loss: 47.9584 - val_mean_absolute_error: 47.9584
# Epoch 216/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 50.5899 - mean_absolute_error: 50.5899 - val_loss: 11.0848 - val_mean_absolute_error: 11.0848
# Epoch 217/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 45.3904 - mean_absolute_error: 45.3904 - val_loss: 28.7937 - val_mean_absolute_error: 28.7937
# Epoch 218/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 45.3102 - mean_absolute_error: 45.3102 - val_loss: 4.9914 - val_mean_absolute_error: 4.9914
# Epoch 219/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.0975 - mean_absolute_error: 47.0975 - val_loss: 34.9403 - val_mean_absolute_error: 34.9403
# Epoch 220/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 53.7805 - mean_absolute_error: 53.7805 - val_loss: 10.6461 - val_mean_absolute_error: 10.6461
# Epoch 221/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 44.7648 - mean_absolute_error: 44.7648 - val_loss: 46.5243 - val_mean_absolute_error: 46.5243
# Epoch 222/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.4652 - mean_absolute_error: 52.4652 - val_loss: 10.6146 - val_mean_absolute_error: 10.6146
# Epoch 223/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.9270 - mean_absolute_error: 47.9270 - val_loss: 8.2037 - val_mean_absolute_error: 8.2037
# Epoch 224/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.0810 - mean_absolute_error: 47.0810 - val_loss: 46.6809 - val_mean_absolute_error: 46.6809
# Epoch 225/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 54.3467 - mean_absolute_error: 54.3467 - val_loss: 42.4512 - val_mean_absolute_error: 42.4512
# Epoch 226/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.3793 - mean_absolute_error: 49.3793 - val_loss: 7.4638 - val_mean_absolute_error: 7.4638
# Epoch 227/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.6946 - mean_absolute_error: 50.6946 - val_loss: 5.3053 - val_mean_absolute_error: 5.3053
# Epoch 228/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.0169 - mean_absolute_error: 48.0169 - val_loss: 33.5441 - val_mean_absolute_error: 33.5441
# Epoch 229/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 48.9182 - mean_absolute_error: 48.9182 - val_loss: 37.5956 - val_mean_absolute_error: 37.5956
# Epoch 230/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 58.3178 - mean_absolute_error: 58.3178 - val_loss: 10.2123 - val_mean_absolute_error: 10.2123
# Epoch 231/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.0210 - mean_absolute_error: 48.0210 - val_loss: 15.0733 - val_mean_absolute_error: 15.0733
# Epoch 232/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.1117 - mean_absolute_error: 49.1117 - val_loss: 31.6021 - val_mean_absolute_error: 31.6021
# Epoch 233/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.8170 - mean_absolute_error: 48.8170 - val_loss: 4.6677 - val_mean_absolute_error: 4.6677
# Epoch 234/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 45.3227 - mean_absolute_error: 45.3227 - val_loss: 16.3233 - val_mean_absolute_error: 16.3233
# Epoch 235/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.3632 - mean_absolute_error: 47.3632 - val_loss: 16.3102 - val_mean_absolute_error: 16.3102
# Epoch 236/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 45.3935 - mean_absolute_error: 45.3935 - val_loss: 35.7129 - val_mean_absolute_error: 35.7129
# Epoch 237/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 51.1841 - mean_absolute_error: 51.1841 - val_loss: 26.2455 - val_mean_absolute_error: 26.2455
# Epoch 238/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 45.9004 - mean_absolute_error: 45.9004 - val_loss: 2.9531 - val_mean_absolute_error: 2.9531
# Epoch 239/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 44.2606 - mean_absolute_error: 44.2606 - val_loss: 4.0766 - val_mean_absolute_error: 4.0766
# Epoch 240/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 46.4002 - mean_absolute_error: 46.4002 - val_loss: 31.8880 - val_mean_absolute_error: 31.8880
# Epoch 241/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.3520 - mean_absolute_error: 48.3520 - val_loss: 33.0332 - val_mean_absolute_error: 33.0332
# Epoch 242/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.1565 - mean_absolute_error: 52.1565 - val_loss: 13.4233 - val_mean_absolute_error: 13.4233
# Epoch 243/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.1265 - mean_absolute_error: 52.1265 - val_loss: 39.7806 - val_mean_absolute_error: 39.7806
# Epoch 244/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 47.6605 - mean_absolute_error: 47.6605 - val_loss: 34.4976 - val_mean_absolute_error: 34.4976
# Epoch 245/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.1479 - mean_absolute_error: 47.1479 - val_loss: 45.4474 - val_mean_absolute_error: 45.4474
# Epoch 246/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 55.7119 - mean_absolute_error: 55.7119 - val_loss: 12.2560 - val_mean_absolute_error: 12.2560
# Epoch 247/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 47.4832 - mean_absolute_error: 47.4832 - val_loss: 36.1349 - val_mean_absolute_error: 36.1349
# Epoch 248/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.2230 - mean_absolute_error: 47.2230 - val_loss: 4.2043 - val_mean_absolute_error: 4.2043
# Epoch 249/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.1918 - mean_absolute_error: 47.1918 - val_loss: 22.4894 - val_mean_absolute_error: 22.4894
# Epoch 250/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 48.3004 - mean_absolute_error: 48.3004 - val_loss: 88.0089 - val_mean_absolute_error: 88.0089
# Epoch 251/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 70.0399 - mean_absolute_error: 70.0399 - val_loss: 15.0397 - val_mean_absolute_error: 15.0397
# Epoch 252/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 45.8548 - mean_absolute_error: 45.8548 - val_loss: 20.6965 - val_mean_absolute_error: 20.6965
# Epoch 253/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 46.7811 - mean_absolute_error: 46.7811 - val_loss: 35.1151 - val_mean_absolute_error: 35.1151
# Epoch 254/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 48.4684 - mean_absolute_error: 48.4684 - val_loss: 8.3207 - val_mean_absolute_error: 8.3207
# Epoch 255/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 45.3825 - mean_absolute_error: 45.3825 - val_loss: 26.5194 - val_mean_absolute_error: 26.5194
# Epoch 256/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 52.3339 - mean_absolute_error: 52.3339 - val_loss: 5.8445 - val_mean_absolute_error: 5.8445
# Epoch 257/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 44.8758 - mean_absolute_error: 44.8758 - val_loss: 12.8729 - val_mean_absolute_error: 12.8729
# Epoch 258/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.7793 - mean_absolute_error: 46.7793 - val_loss: 5.0589 - val_mean_absolute_error: 5.0589
# Epoch 259/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.3581 - mean_absolute_error: 48.3581 - val_loss: 49.7801 - val_mean_absolute_error: 49.7801
# Epoch 260/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 58.6790 - mean_absolute_error: 58.6790 - val_loss: 5.3978 - val_mean_absolute_error: 5.3978
# Epoch 261/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.9188 - mean_absolute_error: 52.9188 - val_loss: 4.9301 - val_mean_absolute_error: 4.9301
# Epoch 262/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 48.0334 - mean_absolute_error: 48.0334 - val_loss: 44.5025 - val_mean_absolute_error: 44.5025
# Epoch 263/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 49.2214 - mean_absolute_error: 49.2214 - val_loss: 18.8715 - val_mean_absolute_error: 18.8715
# Epoch 264/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 55.1798 - mean_absolute_error: 55.1798 - val_loss: 21.4889 - val_mean_absolute_error: 21.4889
# Epoch 265/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.3559 - mean_absolute_error: 48.3559 - val_loss: 26.1794 - val_mean_absolute_error: 26.1794
# Epoch 266/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.3992 - mean_absolute_error: 47.3992 - val_loss: 28.5908 - val_mean_absolute_error: 28.5908
# Epoch 267/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 49.8863 - mean_absolute_error: 49.8863 - val_loss: 34.1397 - val_mean_absolute_error: 34.1397
# Epoch 268/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 49.4531 - mean_absolute_error: 49.4531 - val_loss: 56.2931 - val_mean_absolute_error: 56.2931
# Epoch 269/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.2811 - mean_absolute_error: 52.2811 - val_loss: 38.5973 - val_mean_absolute_error: 38.5973
# Epoch 270/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 51.6820 - mean_absolute_error: 51.6820 - val_loss: 9.8931 - val_mean_absolute_error: 9.8931
# Epoch 271/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 45.9502 - mean_absolute_error: 45.9502 - val_loss: 21.5451 - val_mean_absolute_error: 21.5451
# Epoch 272/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.4626 - mean_absolute_error: 47.4626 - val_loss: 54.0681 - val_mean_absolute_error: 54.0681
# Epoch 273/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 51.9806 - mean_absolute_error: 51.9806 - val_loss: 10.2285 - val_mean_absolute_error: 10.2285
# Epoch 274/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 44.6959 - mean_absolute_error: 44.6959 - val_loss: 20.7475 - val_mean_absolute_error: 20.7475
# Epoch 275/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 48.7898 - mean_absolute_error: 48.7898 - val_loss: 21.7897 - val_mean_absolute_error: 21.7897
# Epoch 276/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 46.3430 - mean_absolute_error: 46.3430 - val_loss: 40.1711 - val_mean_absolute_error: 40.1711
# Epoch 277/2000
# 28/28 [==============================] - 1s 18ms/step - loss: 54.1772 - mean_absolute_error: 54.1772 - val_loss: 18.0092 - val_mean_absolute_error: 18.0092
# Epoch 278/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.1098 - mean_absolute_error: 50.1098 - val_loss: 38.0604 - val_mean_absolute_error: 38.0604
# Epoch 279/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.7682 - mean_absolute_error: 50.7682 - val_loss: 12.5242 - val_mean_absolute_error: 12.5242
# Epoch 280/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.3103 - mean_absolute_error: 46.3103 - val_loss: 7.1222 - val_mean_absolute_error: 7.1222
# Epoch 281/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 47.2695 - mean_absolute_error: 47.2695 - val_loss: 9.5728 - val_mean_absolute_error: 9.5728
# Epoch 282/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 46.4077 - mean_absolute_error: 46.4077 - val_loss: 7.3690 - val_mean_absolute_error: 7.3690
# Epoch 283/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.8832 - mean_absolute_error: 46.8832 - val_loss: 17.2574 - val_mean_absolute_error: 17.2574
# Epoch 284/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 52.3813 - mean_absolute_error: 52.3813 - val_loss: 54.3742 - val_mean_absolute_error: 54.3742
# Epoch 285/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 53.1292 - mean_absolute_error: 53.1292 - val_loss: 13.1212 - val_mean_absolute_error: 13.1212
# Epoch 286/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 43.5565 - mean_absolute_error: 43.5565 - val_loss: 27.5274 - val_mean_absolute_error: 27.5274
# Epoch 287/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.8535 - mean_absolute_error: 50.8535 - val_loss: 49.9117 - val_mean_absolute_error: 49.9117
# Epoch 288/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 54.3378 - mean_absolute_error: 54.3378 - val_loss: 4.8103 - val_mean_absolute_error: 4.8103
# Epoch 289/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.1823 - mean_absolute_error: 46.1823 - val_loss: 24.0784 - val_mean_absolute_error: 24.0784
# Epoch 290/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 46.2845 - mean_absolute_error: 46.2845 - val_loss: 13.8871 - val_mean_absolute_error: 13.8871
# Epoch 291/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 49.5797 - mean_absolute_error: 49.5797 - val_loss: 10.4868 - val_mean_absolute_error: 10.4868
# Epoch 292/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.0752 - mean_absolute_error: 50.0752 - val_loss: 32.4248 - val_mean_absolute_error: 32.4248
# Epoch 293/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 50.3387 - mean_absolute_error: 50.3387 - val_loss: 14.9594 - val_mean_absolute_error: 14.9594
# Epoch 294/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 48.3834 - mean_absolute_error: 48.3834 - val_loss: 28.4311 - val_mean_absolute_error: 28.4311
# Epoch 295/2000
# 28/28 [==============================] - 1s 19ms/step - loss: 52.1474 - mean_absolute_error: 52.1474 - val_loss: 50.3705 - val_mean_absolute_error: 50.3705
# Epoch 296/2000
# 28/28 [==============================] - 1s 20ms/step - loss: 48.4893 - mean_absolute_error: 48.4893 - val_loss: 39.2080 - val_mean_absolute_error: 39.2080

# %%
pred=model.predict([x_test1, x_test])

# %%
#testing prediction
ypred=model.predict([x_test1, x_test])
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score, max_error, mean_squared_log_error, mean_poisson_deviance, mean_gamma_deviance
print('mse: ', mean_squared_error(ypred, y_test1))
print('mae: ', mean_absolute_error(ypred, y_test1))
print('r2_score: ', r2_score(ypred, y_test1))
print('explained_variance_score: ', explained_variance_score(ypred, y_test1))
print('max_error: ', max_error(ypred, y_test1))
print('mean_squared_log_error: ', mean_squared_log_error(ypred, y_test1))
print('mean_poisson_deviance: ', r2_score(ypred, y_test1))
print('mean_gamma_deviance: ',  mean_gamma_deviance(ypred, y_test1))
# Out:
# mse:  6.448515
# mae:  1.8967583
# r2_score:  0.999601346976898
# explained_variance_score:  0.9997091293334961
# max_error:  21.983047
# mean_squared_log_error:  8.1493105e-05
# mean_poisson_deviance:  0.999601346976898
# mean_gamma_deviance:  8.4104075e-05

# %%
#training prediction
xpred=model.predict([x_train1, x_train])
print('mse: ', mean_squared_error(xpred, y_train1))
print('mae: ', mean_absolute_error(xpred, y_train1))
print('r2_score: ', r2_score(xpred, y_train1))
print('explained_variance_score: ', explained_variance_score(xpred, y_train1))
print('max_error: ', max_error(xpred, y_train1))
print('mean_squared_log_error: ', mean_squared_log_error(xpred, y_train1))
print('mean_poisson_deviance: ', r2_score(xpred, y_train1))
print('mean_gamma_deviance: ',  mean_gamma_deviance(xpred, y_train1))
# Out:
# mse:  10.440875
# mae:  2.110066
# r2_score:  0.999660820579582
# explained_variance_score:  0.9996609091758728
# max_error:  42.918808
# mean_squared_log_error:  0.00020721705
# mean_poisson_deviance:  0.999660820579582
# mean_gamma_deviance:  0.00022279404

# %%
import pickle

with pickle.dump()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=40
j=50
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 4)
plt.figure()
plt.plot(xx[i:j],ypred[i:j], color='g', label='RCT', zorder=10)
plt.plot(xx[i:j],y_test1[i:j], color='r', label='Turth value')

plt.scatter(xx[i:j],ypred[i:j],  s=220, zorder=2)
plt.scatter(xx[i:j],y_test1[i:j],  s=220, zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=46)
plt.xlabel('time sequence', fontsize=56)
plt.ylabel('prediction', fontsize=56)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=40
j=50
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 3)
plt.figure()
plt.plot(xx[i:j],trans_y_predict[i:j], color='g', label='Transformer', zorder=10)
plt.plot(xx[i:j],y_test1[i:j], color='r', label='Turth value')

plt.scatter(xx[i:j],trans_y_predict[i:j],  s=120, zorder=2)
plt.scatter(xx[i:j],y_test1[i:j],  s=120, zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=36)
plt.xlabel('time sequence', fontsize=36)
plt.ylabel('prediction', fontsize=36)
plt.show()

# %%
xx=[]
for i in range(len(pred)):
    xx.append(i)

# %%
import pickle
with open('/content/trans_y_predict.pickle', 'rb') as handle:
    trans_y_predict = pickle.load(handle)

with open('/content/trans_x_predict.pickle', 'rb') as handle:
    trans_x_predict = pickle.load(handle)

# %% [markdown]
# *** compare for the testing data***

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=40
j=50
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 4)
plt.figure()
plt.plot(xx[i:j],ypred[i:j], color='g', label='RCT', zorder=10)
plt.plot(xx[i:j],trans_y_predict[i:j], color='b', label='Transformer', zorder=10)
plt.plot(xx[i:j],y_test1[i:j], color='red', label='Turth value')

plt.scatter(xx[i:j],ypred[i:j], color='g', s=220, zorder=2)
plt.scatter(xx[i:j],trans_y_predict[i:j], color='b', s=220, zorder=2)
plt.scatter(xx[i:j],y_test1[i:j],  s=220,color='red', zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=46)
plt.xlabel('time sequence', fontsize=56)
plt.ylabel('prediction', fontsize=56)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=40
j=50
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 3)
plt.figure()
plt.plot(xx[i:j],trans_y_predict[i:j], color='g', label='Turth value', zorder=10)
plt.plot(xx[i:j],y_test1[i:j], color='r', label='Transformer')

plt.scatter(xx[i:j],trans_y_predict[i:j],  s=120, zorder=2)
plt.scatter(xx[i:j],y_test1[i:j],  s=120, zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=36)
plt.xlabel('time sequence', fontsize=36)
plt.ylabel('prediction', fontsize=36)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=50
j=100
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 4)
plt.figure()
plt.plot(xx[i:j],ypred[i:j], color='g', label='RCT', zorder=10)
plt.plot(xx[i:j],trans_y_predict[i:j], color='b', label='Transformer', zorder=10)
plt.plot(xx[i:j],y_test1[i:j], color='red', label='Turth value')

plt.scatter(xx[i:j],ypred[i:j], color='g', s=220, zorder=2)
plt.scatter(xx[i:j],trans_y_predict[i:j], color='b', s=220, zorder=2)
plt.scatter(xx[i:j],y_test1[i:j],  s=220,color='r', zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=46)
plt.xlabel('time sequence', fontsize=56)
plt.ylabel('prediction', fontsize=56)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=0
j=100
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 4)
plt.figure()
plt.plot(xx[i:j],ypred[i:j], color='g', label='RCT', zorder=10)
plt.plot(xx[i:j],trans_y_predict[i:j], color='b', label='Transformer', zorder=10)
plt.plot(xx[i:j],y_test1[i:j], color='red', label='Turth value')

plt.scatter(xx[i:j],ypred[i:j], color='g', s=220, zorder=2)
plt.scatter(xx[i:j],trans_y_predict[i:j], color='b', s=220, zorder=2)
plt.scatter(xx[i:j],y_test1[i:j],  s=220,color='r', zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=46)
plt.xlabel('time sequence', fontsize=56)
plt.ylabel('prediction', fontsize=56)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=0
j=200
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 4)
plt.figure()
plt.plot(xx[i:j],ypred[i:j], color='g', label='RCT', zorder=10)
plt.plot(xx[i:j],trans_y_predict[i:j], color='b', label='Transformer', zorder=10)
plt.plot(xx[i:j],y_test1[i:j], color='red', label='Turth value')

plt.scatter(xx[i:j],ypred[i:j], color='g', s=220, zorder=2)
plt.scatter(xx[i:j],trans_y_predict[i:j], color='b', s=220, zorder=2)
plt.scatter(xx[i:j],y_test1[i:j],  s=220,color='r', zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=46)
plt.xlabel('time sequence', fontsize=56)
plt.ylabel('prediction', fontsize=56)
plt.show()

# %% [markdown]
# * compare for the trainig data

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=40
j=50
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 4)
plt.figure()
plt.plot(xx[i:j],xpred[i:j], color='g', label='RCT', zorder=10)
plt.plot(xx[i:j],trans_x_predict[i:j], color='b', label='Transformer', zorder=10)
plt.plot(xx[i:j],y_train1[i:j], color='red', label='Turth value')

plt.scatter(xx[i:j],xpred[i:j], color='g', s=220, zorder=2)
plt.scatter(xx[i:j],trans_x_predict[i:j], color='b', s=220, zorder=2)
plt.scatter(xx[i:j],y_train1[i:j],  s=220, color='red', zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=46)
plt.xlabel('time sequence', fontsize=56)
plt.ylabel('prediction', fontsize=56)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=40
j=100
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 4)
plt.figure()
plt.plot(xx[i:j],xpred[i:j], color='g', label='RCT', zorder=10)
plt.plot(xx[i:j],trans_x_predict[i:j], color='b', label='Transformer', zorder=10)
plt.plot(xx[i:j],y_train1[i:j], color='red', label='Turth value')

plt.scatter(xx[i:j],xpred[i:j], color='g', s=220, zorder=2)
plt.scatter(xx[i:j],trans_x_predict[i:j], color='b', s=220, zorder=2)
plt.scatter(xx[i:j],y_train1[i:j],  s=220, color='red', zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=46)
plt.xlabel('time sequence', fontsize=56)
plt.ylabel('prediction', fontsize=56)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [40, 20]
i=0
j=500
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 4)
plt.figure()
plt.plot(xx[i:j],xpred[i:j], color='g', label='RCT', zorder=10)
plt.plot(xx[i:j],trans_x_predict[i:j], color='b', label='Transformer', zorder=10)
plt.plot(xx[i:j],y_train1[i:j], color='red', label='Turth value')

plt.scatter(xx[i:j],xpred[i:j], color='g', s=220, zorder=2)
plt.scatter(xx[i:j],trans_x_predict[i:j], color='b', s=220, zorder=2)
plt.scatter(xx[i:j],y_train1[i:j],  s=220, color='red', zorder=2)

plt.legend(loc="upper left", fontsize=36)
plt.title('predict next sequence', fontsize=46)
plt.xlabel('time sequence', fontsize=56)
plt.ylabel('prediction', fontsize=56)
plt.show()
