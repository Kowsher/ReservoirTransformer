# %%
import pandas as pd

df = pd.read_csv('/content/univ-length-over10.short-col-names.csv')

#df=df.drop(columns = ['date'])
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
#df = imputer.fit_transform(df)

from sklearn.preprocessing import LabelEncoder
le1= LabelEncoder()
le2= LabelEncoder()
le3= LabelEncoder()
df['predWillFollowIncreaseCapacity']=le1.fit_transform(df['predWillFollowIncreaseCapacity'])
df['Ft-ULen-Over10-didFollowIncreaseCapacity']=le2.fit_transform(df['Ft-ULen-Over10-didFollowIncreaseCapacity'])

'''
df=df.dropna()
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le1 = LabelEncoder()
le2 = LabelEncoder()
'''


#df['icon']= le.fit_transform(df['icon'])

y = df['Ft-ULen-Over10-didFollowIncreaseCapacity'].values
df=df.drop(columns = ['Ft-ULen-Over10-didFollowIncreaseCapacity'])
X = df.values

# %%
df['Ft-ULen-Over10-didFollowIncreaseCapacity']
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 589     True
# 590    False
# 591     True
# 592     True
# 593     True
# Name: Ft-ULen-Over10-didFollowIncreaseCapacity, Length: 594, dtype: bool

# %%
from collections import Counter
Counter(y)
# Out:
# Counter({0: 359, 1: 235})

# %%
X=X[1:]
y=y[1:]

# %%
for i in range(len(y)):
    if y[i]==2:
        y[i]=1

# %%
y

# %%
y=y.reshape(-1, 1)


import numpy as np
X=np.concatenate((X[1:], y[0:-1]), axis=1)

# %%
pip install keras-self-attention
# Out:
# Collecting keras-self-attention
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-self-attention) (1.21.5)
# Building wheels for collected packages: keras-self-attention
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18912 sha256=d9239fc7fe51bf4f9cdbaa5ea16855eb7d4f4c51cb788fae3eb0db7ec387bc00
#   Stored in directory: /root/.cache/pip/wheels/95/b1/a8/5ee00cc137940b2f6fa198212e8f45d813d0e0d9c3a04035a3
# Successfully built keras-self-attention
# Installing collected packages: keras-self-attention
# Successfully installed keras-self-attention-0.51.0

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X= sc.fit_transform(X)

# %%
pip install pyrcn
# Out:
# Collecting pyrcn
#   Downloading PyRCN-0.0.16.post1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 6.1 MB/s
# Installing collected packages: pyrcn
# Successfully installed pyrcn-0.0.16.post1

# %%
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1 = train_test_split(X, y[1:], test_size=0.2, shuffle=False, random_state=42)

# %%
x_train1.shape
# Out:
# (474, 20)

# %%
from pyrcn.base.blocks import InputToNode
from sklearn . datasets import make_blobs
# Generate a toy dataset

# %%
input_to_node = InputToNode (35, input_activation='relu',input_scaling =1.0 )


x_train= input_to_node.fit_transform (x_train1)
x_test= input_to_node.transform (x_test1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:77: FutureWarning: Pass hidden_layer_size=35 as keyword args. From version 1.1 (renaming of 0.26) passing these as positional arguments will result in an error
#   FutureWarning,

# %%
from pyrcn.base.blocks import NodeToNode
node_to_node = NodeToNode (35, reservoir_activation='relu', spectral_radius =1.0 , leakage =0.8 ,bidirectional = True )
x_train=node_to_node . fit_transform(x_train)
x_test= node_to_node.transform (x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:77: FutureWarning: Pass hidden_layer_size=35 as keyword args. From version 1.1 (renaming of 0.26) passing these as positional arguments will result in an error
#   FutureWarning,

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

x_train1 = x_train1.reshape((x_train1.shape[0], x_train1.shape[1], 1))
x_test1 = x_test1.reshape((x_test1.shape[0], x_test1.shape[1], 1))

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
from keras_self_attention import SeqSelfAttention
def build_model(
    input_shapey,
    input_shapez,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputsy = keras.Input(shape=input_shapey)
    inputsz = keras.Input(shape=input_shapez)
    y = inputsy
    z= inputsz

    #z=layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(z)

    #y=layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(y)

    z=SeqSelfAttention()(z)

    #y=SeqSelfAttention()(y)



    x=layers.Concatenate(axis=1)([y, z])
    #x=layers.Add()([inputsy, inputsz])

    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(2, activation="softmax")(x)
    #outputs = layers.Dense(1)(x)
    return keras.Model([inputsy,inputsz], outputs)

# %%
input_shapey = x_train1.shape[1:]
input_shapez = x_train.shape[1:]

model = build_model(
    input_shapey,
    input_shapez,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)
'''
model.compile(
    loss="mean_absolute_error",
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["mean_absolute_error"],
)
'''
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["sparse_categorical_accuracy"],
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 70, 1)]      0           []
#
#  input_1 (InputLayer)           [(None, 20, 1)]      0           []
#
#  seq_self_attention (SeqSelfAtt  (None, 70, 1)       129         ['input_2[0][0]']
#  ention)
#
#  concatenate (Concatenate)      (None, 90, 1)        0           ['input_1[0][0]',
#                                                                   'seq_self_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 90, 1)       2           ['concatenate[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 90, 1)       7169        ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout (Dropout)              (None, 90, 1)        0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 90, 1)       0           ['dropout[0][0]',
#  da)                                                              'concatenate[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 90, 1)       2           ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 90, 4)        8           ['layer_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 90, 4)        0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 90, 1)        5           ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 90, 1)       0           ['conv1d_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 90, 1)       2           ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 90, 1)       7169        ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 90, 1)        0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 90, 1)       0           ['dropout_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 90, 1)       2           ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  conv1d_2 (Conv1D)              (None, 90, 4)        8           ['layer_normalization_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 90, 4)        0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 90, 1)        5           ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 90, 1)       0           ['conv1d_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 90, 1)       2           ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 90, 1)       7169        ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 90, 1)        0           ['multi_head_attention_2[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 90, 1)       0           ['dropout_4[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 90, 1)       2           ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  conv1d_4 (Conv1D)              (None, 90, 4)        8           ['layer_normalization_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 90, 4)        0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 90, 1)        5           ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 90, 1)       0           ['conv1d_5[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 90, 1)       2           ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 90, 1)       7169        ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  dropout_6 (Dropout)            (None, 90, 1)        0           ['multi_head_attention_3[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 90, 1)       0           ['dropout_6[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 90, 1)       2           ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  conv1d_6 (Conv1D)              (None, 90, 4)        8           ['layer_normalization_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 90, 4)        0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 90, 1)        5           ['dropout_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 90, 1)       0           ['conv1d_7[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 90)          0           ['tf.__operators__.add_7[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 128)          11648       ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_8 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2)            258         ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 40,779
# Trainable params: 40,779
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callbacks = [keras.callbacks.EarlyStopping(patience=700, restore_best_weights=True)]

history=model.fit(
    [x_train1,x_train],
    y_train1,
    validation_data=([x_test1, x_test], y_test1),
    epochs=2000,
    batch_size=128,
    callbacks=callbacks,
)
# Out:
# Epoch 1/2000
# 4/4 [==============================] - 7s 324ms/step - loss: 0.8231 - sparse_categorical_accuracy: 0.5370 - val_loss: 0.6628 - val_sparse_categorical_accuracy: 0.6050
# Epoch 2/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.7384 - sparse_categorical_accuracy: 0.5349 - val_loss: 0.6019 - val_sparse_categorical_accuracy: 0.6303
# Epoch 3/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.6823 - sparse_categorical_accuracy: 0.5814 - val_loss: 0.5693 - val_sparse_categorical_accuracy: 0.6303
# Epoch 4/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.6277 - sparse_categorical_accuracy: 0.6723 - val_loss: 0.5634 - val_sparse_categorical_accuracy: 0.6134
# Epoch 5/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5907 - sparse_categorical_accuracy: 0.7019 - val_loss: 0.5445 - val_sparse_categorical_accuracy: 0.7059
# Epoch 6/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.5961 - sparse_categorical_accuracy: 0.6808 - val_loss: 0.5407 - val_sparse_categorical_accuracy: 0.7143
# Epoch 7/2000
# 4/4 [==============================] - 0s 118ms/step - loss: 0.5829 - sparse_categorical_accuracy: 0.7082 - val_loss: 0.5368 - val_sparse_categorical_accuracy: 0.7143
# Epoch 8/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.5641 - sparse_categorical_accuracy: 0.7125 - val_loss: 0.5317 - val_sparse_categorical_accuracy: 0.7227
# Epoch 9/2000
# 4/4 [==============================] - 0s 101ms/step - loss: 0.5397 - sparse_categorical_accuracy: 0.7273 - val_loss: 0.5318 - val_sparse_categorical_accuracy: 0.7395
# Epoch 10/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5527 - sparse_categorical_accuracy: 0.7315 - val_loss: 0.5282 - val_sparse_categorical_accuracy: 0.7395
# Epoch 11/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5605 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.5255 - val_sparse_categorical_accuracy: 0.7311
# Epoch 12/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5579 - sparse_categorical_accuracy: 0.7167 - val_loss: 0.5253 - val_sparse_categorical_accuracy: 0.7311
# Epoch 13/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5443 - sparse_categorical_accuracy: 0.7273 - val_loss: 0.5218 - val_sparse_categorical_accuracy: 0.7479
# Epoch 14/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5363 - sparse_categorical_accuracy: 0.7632 - val_loss: 0.5192 - val_sparse_categorical_accuracy: 0.7479
# Epoch 15/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.5337 - sparse_categorical_accuracy: 0.7442 - val_loss: 0.5152 - val_sparse_categorical_accuracy: 0.7563
# Epoch 16/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.5471 - sparse_categorical_accuracy: 0.7400 - val_loss: 0.5096 - val_sparse_categorical_accuracy: 0.7647
# Epoch 17/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.5327 - sparse_categorical_accuracy: 0.7674 - val_loss: 0.5062 - val_sparse_categorical_accuracy: 0.7563
# Epoch 18/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5141 - sparse_categorical_accuracy: 0.7632 - val_loss: 0.5031 - val_sparse_categorical_accuracy: 0.7563
# Epoch 19/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5277 - sparse_categorical_accuracy: 0.7590 - val_loss: 0.5004 - val_sparse_categorical_accuracy: 0.7647
# Epoch 20/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5049 - sparse_categorical_accuracy: 0.7653 - val_loss: 0.4994 - val_sparse_categorical_accuracy: 0.7647
# Epoch 21/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.5153 - sparse_categorical_accuracy: 0.7780 - val_loss: 0.4981 - val_sparse_categorical_accuracy: 0.7647
# Epoch 22/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.5020 - sparse_categorical_accuracy: 0.7696 - val_loss: 0.4948 - val_sparse_categorical_accuracy: 0.7647
# Epoch 23/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.5167 - sparse_categorical_accuracy: 0.7696 - val_loss: 0.4939 - val_sparse_categorical_accuracy: 0.7731
# Epoch 24/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.4955 - sparse_categorical_accuracy: 0.7801 - val_loss: 0.4927 - val_sparse_categorical_accuracy: 0.7731
# Epoch 25/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4956 - sparse_categorical_accuracy: 0.7907 - val_loss: 0.4905 - val_sparse_categorical_accuracy: 0.7563
# Epoch 26/2000
# 4/4 [==============================] - 0s 102ms/step - loss: 0.4763 - sparse_categorical_accuracy: 0.7759 - val_loss: 0.4908 - val_sparse_categorical_accuracy: 0.7479
# Epoch 27/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.4897 - sparse_categorical_accuracy: 0.7548 - val_loss: 0.4893 - val_sparse_categorical_accuracy: 0.7563
# Epoch 28/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4872 - sparse_categorical_accuracy: 0.7780 - val_loss: 0.4862 - val_sparse_categorical_accuracy: 0.7563
# Epoch 29/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.4883 - sparse_categorical_accuracy: 0.7801 - val_loss: 0.4823 - val_sparse_categorical_accuracy: 0.7563
# Epoch 30/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.4813 - sparse_categorical_accuracy: 0.7886 - val_loss: 0.4814 - val_sparse_categorical_accuracy: 0.7647
# Epoch 31/2000
# 4/4 [==============================] - 0s 102ms/step - loss: 0.4834 - sparse_categorical_accuracy: 0.7865 - val_loss: 0.4857 - val_sparse_categorical_accuracy: 0.7563
# Epoch 32/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.4839 - sparse_categorical_accuracy: 0.7928 - val_loss: 0.4820 - val_sparse_categorical_accuracy: 0.7563
# Epoch 33/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4918 - sparse_categorical_accuracy: 0.7865 - val_loss: 0.4771 - val_sparse_categorical_accuracy: 0.7815
# Epoch 34/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.4764 - sparse_categorical_accuracy: 0.7801 - val_loss: 0.4765 - val_sparse_categorical_accuracy: 0.7731
# Epoch 35/2000
# 4/4 [==============================] - 0s 102ms/step - loss: 0.4601 - sparse_categorical_accuracy: 0.8118 - val_loss: 0.4772 - val_sparse_categorical_accuracy: 0.7731
# Epoch 36/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.4619 - sparse_categorical_accuracy: 0.7992 - val_loss: 0.4763 - val_sparse_categorical_accuracy: 0.7731
# Epoch 37/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4693 - sparse_categorical_accuracy: 0.7801 - val_loss: 0.4733 - val_sparse_categorical_accuracy: 0.7731
# Epoch 38/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4581 - sparse_categorical_accuracy: 0.7696 - val_loss: 0.4703 - val_sparse_categorical_accuracy: 0.7815
# Epoch 39/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4478 - sparse_categorical_accuracy: 0.7844 - val_loss: 0.4683 - val_sparse_categorical_accuracy: 0.7815
# Epoch 40/2000
# 4/4 [==============================] - 0s 113ms/step - loss: 0.4561 - sparse_categorical_accuracy: 0.7801 - val_loss: 0.4672 - val_sparse_categorical_accuracy: 0.7815
# Epoch 41/2000
# 4/4 [==============================] - 0s 133ms/step - loss: 0.4447 - sparse_categorical_accuracy: 0.8097 - val_loss: 0.4651 - val_sparse_categorical_accuracy: 0.7731
# Epoch 42/2000
# 4/4 [==============================] - 0s 103ms/step - loss: 0.4510 - sparse_categorical_accuracy: 0.7992 - val_loss: 0.4659 - val_sparse_categorical_accuracy: 0.7899
# Epoch 43/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.4498 - sparse_categorical_accuracy: 0.7949 - val_loss: 0.4662 - val_sparse_categorical_accuracy: 0.7899
# Epoch 44/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.4368 - sparse_categorical_accuracy: 0.8076 - val_loss: 0.4612 - val_sparse_categorical_accuracy: 0.7899
# Epoch 45/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4412 - sparse_categorical_accuracy: 0.7907 - val_loss: 0.4584 - val_sparse_categorical_accuracy: 0.7899
# Epoch 46/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4368 - sparse_categorical_accuracy: 0.7970 - val_loss: 0.4550 - val_sparse_categorical_accuracy: 0.7983
# Epoch 47/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.4346 - sparse_categorical_accuracy: 0.8013 - val_loss: 0.4530 - val_sparse_categorical_accuracy: 0.7983
# Epoch 48/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.4412 - sparse_categorical_accuracy: 0.7949 - val_loss: 0.4516 - val_sparse_categorical_accuracy: 0.7983
# Epoch 49/2000
# 4/4 [==============================] - 0s 103ms/step - loss: 0.4157 - sparse_categorical_accuracy: 0.8140 - val_loss: 0.4516 - val_sparse_categorical_accuracy: 0.7983
# Epoch 50/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4414 - sparse_categorical_accuracy: 0.7928 - val_loss: 0.4487 - val_sparse_categorical_accuracy: 0.7983
# Epoch 51/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.4164 - sparse_categorical_accuracy: 0.8055 - val_loss: 0.4489 - val_sparse_categorical_accuracy: 0.7983
# Epoch 52/2000
# 4/4 [==============================] - 0s 103ms/step - loss: 0.4319 - sparse_categorical_accuracy: 0.7992 - val_loss: 0.4505 - val_sparse_categorical_accuracy: 0.7983
# Epoch 53/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.4279 - sparse_categorical_accuracy: 0.8097 - val_loss: 0.4500 - val_sparse_categorical_accuracy: 0.7983
# Epoch 54/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.4219 - sparse_categorical_accuracy: 0.8034 - val_loss: 0.4475 - val_sparse_categorical_accuracy: 0.7983
# Epoch 55/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4271 - sparse_categorical_accuracy: 0.8182 - val_loss: 0.4428 - val_sparse_categorical_accuracy: 0.7983
# Epoch 56/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4231 - sparse_categorical_accuracy: 0.8140 - val_loss: 0.4416 - val_sparse_categorical_accuracy: 0.7983
# Epoch 57/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.4064 - sparse_categorical_accuracy: 0.8034 - val_loss: 0.4389 - val_sparse_categorical_accuracy: 0.7983
# Epoch 58/2000
# 4/4 [==============================] - 0s 103ms/step - loss: 0.4232 - sparse_categorical_accuracy: 0.8118 - val_loss: 0.4393 - val_sparse_categorical_accuracy: 0.7983
# Epoch 59/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.4049 - sparse_categorical_accuracy: 0.8055 - val_loss: 0.4392 - val_sparse_categorical_accuracy: 0.7983
# Epoch 60/2000
# 4/4 [==============================] - 0s 121ms/step - loss: 0.3955 - sparse_categorical_accuracy: 0.8372 - val_loss: 0.4366 - val_sparse_categorical_accuracy: 0.7983
# Epoch 61/2000
# 4/4 [==============================] - 0s 119ms/step - loss: 0.3920 - sparse_categorical_accuracy: 0.8182 - val_loss: 0.4338 - val_sparse_categorical_accuracy: 0.7983
# Epoch 62/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.4009 - sparse_categorical_accuracy: 0.8182 - val_loss: 0.4313 - val_sparse_categorical_accuracy: 0.7983
# Epoch 63/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.3940 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.4317 - val_sparse_categorical_accuracy: 0.7983
# Epoch 64/2000
# 4/4 [==============================] - 0s 119ms/step - loss: 0.3925 - sparse_categorical_accuracy: 0.8245 - val_loss: 0.4262 - val_sparse_categorical_accuracy: 0.8067
# Epoch 65/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.3880 - sparse_categorical_accuracy: 0.8245 - val_loss: 0.4269 - val_sparse_categorical_accuracy: 0.8067
# Epoch 66/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.3957 - sparse_categorical_accuracy: 0.8309 - val_loss: 0.4253 - val_sparse_categorical_accuracy: 0.8067
# Epoch 67/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.3838 - sparse_categorical_accuracy: 0.8351 - val_loss: 0.4199 - val_sparse_categorical_accuracy: 0.8235
# Epoch 68/2000
# 4/4 [==============================] - 0s 103ms/step - loss: 0.3902 - sparse_categorical_accuracy: 0.8203 - val_loss: 0.4210 - val_sparse_categorical_accuracy: 0.8067
# Epoch 69/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.3991 - sparse_categorical_accuracy: 0.8203 - val_loss: 0.4205 - val_sparse_categorical_accuracy: 0.8067
# Epoch 70/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.3816 - sparse_categorical_accuracy: 0.8224 - val_loss: 0.4206 - val_sparse_categorical_accuracy: 0.7983
# Epoch 71/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.3687 - sparse_categorical_accuracy: 0.8224 - val_loss: 0.4169 - val_sparse_categorical_accuracy: 0.8067
# Epoch 72/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.3792 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.4144 - val_sparse_categorical_accuracy: 0.8151
# Epoch 73/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.3628 - sparse_categorical_accuracy: 0.8457 - val_loss: 0.4119 - val_sparse_categorical_accuracy: 0.8151
# Epoch 74/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.3635 - sparse_categorical_accuracy: 0.8457 - val_loss: 0.4117 - val_sparse_categorical_accuracy: 0.8151
# Epoch 75/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.3717 - sparse_categorical_accuracy: 0.8351 - val_loss: 0.4095 - val_sparse_categorical_accuracy: 0.8151
# Epoch 76/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3681 - sparse_categorical_accuracy: 0.8478 - val_loss: 0.4094 - val_sparse_categorical_accuracy: 0.8151
# Epoch 77/2000
# 4/4 [==============================] - 0s 114ms/step - loss: 0.3605 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.4106 - val_sparse_categorical_accuracy: 0.8151
# Epoch 78/2000
# 4/4 [==============================] - 0s 114ms/step - loss: 0.3689 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.4060 - val_sparse_categorical_accuracy: 0.8151
# Epoch 79/2000
# 4/4 [==============================] - 1s 138ms/step - loss: 0.3400 - sparse_categorical_accuracy: 0.8562 - val_loss: 0.4013 - val_sparse_categorical_accuracy: 0.8235
# Epoch 80/2000
# 4/4 [==============================] - 1s 147ms/step - loss: 0.3416 - sparse_categorical_accuracy: 0.8520 - val_loss: 0.3956 - val_sparse_categorical_accuracy: 0.8319
# Epoch 81/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3386 - sparse_categorical_accuracy: 0.8605 - val_loss: 0.3920 - val_sparse_categorical_accuracy: 0.8235
# Epoch 82/2000
# 4/4 [==============================] - 1s 157ms/step - loss: 0.3363 - sparse_categorical_accuracy: 0.8562 - val_loss: 0.3908 - val_sparse_categorical_accuracy: 0.8319
# Epoch 83/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.3232 - sparse_categorical_accuracy: 0.8520 - val_loss: 0.3885 - val_sparse_categorical_accuracy: 0.8319
# Epoch 84/2000
# 4/4 [==============================] - 0s 133ms/step - loss: 0.3197 - sparse_categorical_accuracy: 0.8732 - val_loss: 0.3799 - val_sparse_categorical_accuracy: 0.8151
# Epoch 85/2000
# 4/4 [==============================] - 1s 152ms/step - loss: 0.3385 - sparse_categorical_accuracy: 0.8414 - val_loss: 0.3749 - val_sparse_categorical_accuracy: 0.8151
# Epoch 86/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.3278 - sparse_categorical_accuracy: 0.8414 - val_loss: 0.3751 - val_sparse_categorical_accuracy: 0.8235
# Epoch 87/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3180 - sparse_categorical_accuracy: 0.8562 - val_loss: 0.3626 - val_sparse_categorical_accuracy: 0.8067
# Epoch 88/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3029 - sparse_categorical_accuracy: 0.8520 - val_loss: 0.3572 - val_sparse_categorical_accuracy: 0.8151
# Epoch 89/2000
# 4/4 [==============================] - 0s 113ms/step - loss: 0.3007 - sparse_categorical_accuracy: 0.8710 - val_loss: 0.3556 - val_sparse_categorical_accuracy: 0.8319
# Epoch 90/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.2963 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.3572 - val_sparse_categorical_accuracy: 0.8319
# Epoch 91/2000
# 4/4 [==============================] - 0s 113ms/step - loss: 0.2927 - sparse_categorical_accuracy: 0.8668 - val_loss: 0.3504 - val_sparse_categorical_accuracy: 0.8319
# Epoch 92/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.2865 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.3431 - val_sparse_categorical_accuracy: 0.8235
# Epoch 93/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2574 - sparse_categorical_accuracy: 0.8964 - val_loss: 0.3367 - val_sparse_categorical_accuracy: 0.8403
# Epoch 94/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.2835 - sparse_categorical_accuracy: 0.8858 - val_loss: 0.3384 - val_sparse_categorical_accuracy: 0.8319
# Epoch 95/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2769 - sparse_categorical_accuracy: 0.8816 - val_loss: 0.3295 - val_sparse_categorical_accuracy: 0.8403
# Epoch 96/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2511 - sparse_categorical_accuracy: 0.8837 - val_loss: 0.3239 - val_sparse_categorical_accuracy: 0.8571
# Epoch 97/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.2324 - sparse_categorical_accuracy: 0.9006 - val_loss: 0.3191 - val_sparse_categorical_accuracy: 0.8571
# Epoch 98/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.2422 - sparse_categorical_accuracy: 0.9006 - val_loss: 0.3088 - val_sparse_categorical_accuracy: 0.8655
# Epoch 99/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2340 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.3005 - val_sparse_categorical_accuracy: 0.8739
# Epoch 100/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.2094 - sparse_categorical_accuracy: 0.9239 - val_loss: 0.3006 - val_sparse_categorical_accuracy: 0.8655
# Epoch 101/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.2298 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.2833 - val_sparse_categorical_accuracy: 0.8824
# Epoch 102/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.2209 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.2811 - val_sparse_categorical_accuracy: 0.8739
# Epoch 103/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.2272 - sparse_categorical_accuracy: 0.9070 - val_loss: 0.2818 - val_sparse_categorical_accuracy: 0.8739
# Epoch 104/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.1955 - sparse_categorical_accuracy: 0.9281 - val_loss: 0.2777 - val_sparse_categorical_accuracy: 0.8739
# Epoch 105/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.1982 - sparse_categorical_accuracy: 0.9387 - val_loss: 0.2670 - val_sparse_categorical_accuracy: 0.8739
# Epoch 106/2000
# 4/4 [==============================] - 0s 120ms/step - loss: 0.1909 - sparse_categorical_accuracy: 0.9281 - val_loss: 0.2586 - val_sparse_categorical_accuracy: 0.8824
# Epoch 107/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.1681 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.2605 - val_sparse_categorical_accuracy: 0.8908
# Epoch 108/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.1805 - sparse_categorical_accuracy: 0.9239 - val_loss: 0.2557 - val_sparse_categorical_accuracy: 0.8824
# Epoch 109/2000
# 4/4 [==============================] - 0s 120ms/step - loss: 0.1799 - sparse_categorical_accuracy: 0.9408 - val_loss: 0.2523 - val_sparse_categorical_accuracy: 0.8908
# Epoch 110/2000
# 4/4 [==============================] - 0s 117ms/step - loss: 0.1547 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.2468 - val_sparse_categorical_accuracy: 0.8992
# Epoch 111/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.1794 - sparse_categorical_accuracy: 0.9197 - val_loss: 0.2586 - val_sparse_categorical_accuracy: 0.8824
# Epoch 112/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.2705 - val_sparse_categorical_accuracy: 0.8908
# Epoch 113/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.1481 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.2475 - val_sparse_categorical_accuracy: 0.8824
# Epoch 114/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.1486 - sparse_categorical_accuracy: 0.9429 - val_loss: 0.2395 - val_sparse_categorical_accuracy: 0.8908
# Epoch 115/2000
# 4/4 [==============================] - 0s 113ms/step - loss: 0.1323 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.2386 - val_sparse_categorical_accuracy: 0.8739
# Epoch 116/2000
# 4/4 [==============================] - 0s 122ms/step - loss: 0.1378 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.2273 - val_sparse_categorical_accuracy: 0.8824
# Epoch 117/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.1283 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.2203 - val_sparse_categorical_accuracy: 0.8908
# Epoch 118/2000
# 4/4 [==============================] - 0s 113ms/step - loss: 0.1282 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.2195 - val_sparse_categorical_accuracy: 0.8992
# Epoch 119/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.1135 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.2273 - val_sparse_categorical_accuracy: 0.8908
# Epoch 120/2000
# 4/4 [==============================] - 0s 125ms/step - loss: 0.1082 - sparse_categorical_accuracy: 0.9704 - val_loss: 0.2190 - val_sparse_categorical_accuracy: 0.8908
# Epoch 121/2000
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0986 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.2115 - val_sparse_categorical_accuracy: 0.8824
# Epoch 122/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.1003 - sparse_categorical_accuracy: 0.9810 - val_loss: 0.2189 - val_sparse_categorical_accuracy: 0.8908
# Epoch 123/2000
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0948 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.2098 - val_sparse_categorical_accuracy: 0.8908
# Epoch 124/2000
# 4/4 [==============================] - 0s 124ms/step - loss: 0.1036 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.2057 - val_sparse_categorical_accuracy: 0.8908
# Epoch 125/2000
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0842 - sparse_categorical_accuracy: 0.9810 - val_loss: 0.2017 - val_sparse_categorical_accuracy: 0.8908
# Epoch 126/2000
# 4/4 [==============================] - 0s 123ms/step - loss: 0.1049 - sparse_categorical_accuracy: 0.9598 - val_loss: 0.1933 - val_sparse_categorical_accuracy: 0.9076
# Epoch 127/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0969 - sparse_categorical_accuracy: 0.9704 - val_loss: 0.1931 - val_sparse_categorical_accuracy: 0.9076
# Epoch 128/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0846 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.1984 - val_sparse_categorical_accuracy: 0.8908
# Epoch 129/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0892 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.1985 - val_sparse_categorical_accuracy: 0.9076
# Epoch 130/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0905 - sparse_categorical_accuracy: 0.9641 - val_loss: 0.2036 - val_sparse_categorical_accuracy: 0.8992
# Epoch 131/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0747 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.2050 - val_sparse_categorical_accuracy: 0.8992
# Epoch 132/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0731 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.2039 - val_sparse_categorical_accuracy: 0.8908
# Epoch 133/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0769 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.2039 - val_sparse_categorical_accuracy: 0.9160
# Epoch 134/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0696 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.1961 - val_sparse_categorical_accuracy: 0.9328
# Epoch 135/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0644 - sparse_categorical_accuracy: 0.9831 - val_loss: 0.1992 - val_sparse_categorical_accuracy: 0.9160
# Epoch 136/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0670 - sparse_categorical_accuracy: 0.9873 - val_loss: 0.1908 - val_sparse_categorical_accuracy: 0.9160
# Epoch 137/2000
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0686 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1886 - val_sparse_categorical_accuracy: 0.9244
# Epoch 138/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0625 - sparse_categorical_accuracy: 0.9873 - val_loss: 0.1872 - val_sparse_categorical_accuracy: 0.9076
# Epoch 139/2000
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0504 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.1869 - val_sparse_categorical_accuracy: 0.9076
# Epoch 140/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0600 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.1915 - val_sparse_categorical_accuracy: 0.9244
# Epoch 141/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0632 - sparse_categorical_accuracy: 0.9810 - val_loss: 0.1913 - val_sparse_categorical_accuracy: 0.9076
# Epoch 142/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0569 - sparse_categorical_accuracy: 0.9810 - val_loss: 0.1951 - val_sparse_categorical_accuracy: 0.9076
# Epoch 143/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0576 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.1933 - val_sparse_categorical_accuracy: 0.9160
# Epoch 144/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0481 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.2045 - val_sparse_categorical_accuracy: 0.8992
# Epoch 145/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0572 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.2034 - val_sparse_categorical_accuracy: 0.9076
# Epoch 146/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0515 - sparse_categorical_accuracy: 0.9831 - val_loss: 0.2033 - val_sparse_categorical_accuracy: 0.9160
# Epoch 147/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.2068 - val_sparse_categorical_accuracy: 0.9160
# Epoch 148/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0429 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.2149 - val_sparse_categorical_accuracy: 0.9160
# Epoch 149/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0520 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.1984 - val_sparse_categorical_accuracy: 0.9160
# Epoch 150/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0419 - sparse_categorical_accuracy: 0.9873 - val_loss: 0.1943 - val_sparse_categorical_accuracy: 0.9244
# Epoch 151/2000
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9831 - val_loss: 0.2031 - val_sparse_categorical_accuracy: 0.9244
# Epoch 152/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9831 - val_loss: 0.2087 - val_sparse_categorical_accuracy: 0.9244
# Epoch 153/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0466 - sparse_categorical_accuracy: 0.9873 - val_loss: 0.1983 - val_sparse_categorical_accuracy: 0.9244
# Epoch 154/2000
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0370 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.1984 - val_sparse_categorical_accuracy: 0.9160
# Epoch 155/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0421 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2080 - val_sparse_categorical_accuracy: 0.9244
# Epoch 156/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0359 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2051 - val_sparse_categorical_accuracy: 0.9244
# Epoch 157/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0349 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.1975 - val_sparse_categorical_accuracy: 0.9328
# Epoch 158/2000
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0239 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1981 - val_sparse_categorical_accuracy: 0.9328
# Epoch 159/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.1991 - val_sparse_categorical_accuracy: 0.9328
# Epoch 160/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0333 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2007 - val_sparse_categorical_accuracy: 0.9328
# Epoch 161/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0344 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2030 - val_sparse_categorical_accuracy: 0.9328
# Epoch 162/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.2076 - val_sparse_categorical_accuracy: 0.9328
# Epoch 163/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0376 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2150 - val_sparse_categorical_accuracy: 0.9244
# Epoch 164/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2185 - val_sparse_categorical_accuracy: 0.9244
# Epoch 165/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0353 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2068 - val_sparse_categorical_accuracy: 0.9160
# Epoch 166/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2057 - val_sparse_categorical_accuracy: 0.9328
# Epoch 167/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0345 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2029 - val_sparse_categorical_accuracy: 0.9328
# Epoch 168/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2197 - val_sparse_categorical_accuracy: 0.9160
# Epoch 169/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2177 - val_sparse_categorical_accuracy: 0.9160
# Epoch 170/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0272 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.2138 - val_sparse_categorical_accuracy: 0.9328
# Epoch 171/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0301 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2125 - val_sparse_categorical_accuracy: 0.9328
# Epoch 172/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0318 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.2084 - val_sparse_categorical_accuracy: 0.9328
# Epoch 173/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0264 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.2109 - val_sparse_categorical_accuracy: 0.9328
# Epoch 174/2000
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0253 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2207 - val_sparse_categorical_accuracy: 0.9160
# Epoch 175/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0217 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2081 - val_sparse_categorical_accuracy: 0.9328
# Epoch 176/2000
# 4/4 [==============================] - 0s 118ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2088 - val_sparse_categorical_accuracy: 0.9328
# Epoch 177/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0198 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2126 - val_sparse_categorical_accuracy: 0.9328
# Epoch 178/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0335 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.2217 - val_sparse_categorical_accuracy: 0.9244
# Epoch 179/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2306 - val_sparse_categorical_accuracy: 0.9244
# Epoch 180/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0219 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2169 - val_sparse_categorical_accuracy: 0.9244
# Epoch 181/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0212 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2167 - val_sparse_categorical_accuracy: 0.9244
# Epoch 182/2000
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0215 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2210 - val_sparse_categorical_accuracy: 0.9244
# Epoch 183/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2146 - val_sparse_categorical_accuracy: 0.9244
# Epoch 184/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0202 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2086 - val_sparse_categorical_accuracy: 0.9328
# Epoch 185/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2077 - val_sparse_categorical_accuracy: 0.9328
# Epoch 186/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0191 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2089 - val_sparse_categorical_accuracy: 0.9328
# Epoch 187/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2103 - val_sparse_categorical_accuracy: 0.9328
# Epoch 188/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0138 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2117 - val_sparse_categorical_accuracy: 0.9328
# Epoch 189/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2156 - val_sparse_categorical_accuracy: 0.9328
# Epoch 190/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0231 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2197 - val_sparse_categorical_accuracy: 0.9328
# Epoch 191/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2283 - val_sparse_categorical_accuracy: 0.9244
# Epoch 192/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0183 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2306 - val_sparse_categorical_accuracy: 0.9244
# Epoch 193/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0129 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2229 - val_sparse_categorical_accuracy: 0.9328
# Epoch 194/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2300 - val_sparse_categorical_accuracy: 0.9328
# Epoch 195/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0180 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2320 - val_sparse_categorical_accuracy: 0.9328
# Epoch 196/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0238 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2386 - val_sparse_categorical_accuracy: 0.9244
# Epoch 197/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2393 - val_sparse_categorical_accuracy: 0.9244
# Epoch 198/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2401 - val_sparse_categorical_accuracy: 0.9244
# Epoch 199/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0184 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2348 - val_sparse_categorical_accuracy: 0.9244
# Epoch 200/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0158 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2300 - val_sparse_categorical_accuracy: 0.9160
# Epoch 201/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0253 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2264 - val_sparse_categorical_accuracy: 0.9244
# Epoch 202/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0145 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2239 - val_sparse_categorical_accuracy: 0.9328
# Epoch 203/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.2189 - val_sparse_categorical_accuracy: 0.9328
# Epoch 204/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0168 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2138 - val_sparse_categorical_accuracy: 0.9328
# Epoch 205/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2115 - val_sparse_categorical_accuracy: 0.9328
# Epoch 206/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0114 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2138 - val_sparse_categorical_accuracy: 0.9328
# Epoch 207/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2168 - val_sparse_categorical_accuracy: 0.9328
# Epoch 208/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2164 - val_sparse_categorical_accuracy: 0.9412
# Epoch 209/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2171 - val_sparse_categorical_accuracy: 0.9328
# Epoch 210/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2237 - val_sparse_categorical_accuracy: 0.9328
# Epoch 211/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2275 - val_sparse_categorical_accuracy: 0.9328
# Epoch 212/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.2301 - val_sparse_categorical_accuracy: 0.9328
# Epoch 213/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2384 - val_sparse_categorical_accuracy: 0.9412
# Epoch 214/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0130 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2310 - val_sparse_categorical_accuracy: 0.9328
# Epoch 215/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0147 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2281 - val_sparse_categorical_accuracy: 0.9328
# Epoch 216/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0139 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2292 - val_sparse_categorical_accuracy: 0.9328
# Epoch 217/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0097 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2370 - val_sparse_categorical_accuracy: 0.9328
# Epoch 218/2000
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2554 - val_sparse_categorical_accuracy: 0.9328
# Epoch 219/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0180 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2434 - val_sparse_categorical_accuracy: 0.9328
# Epoch 220/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0094 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2332 - val_sparse_categorical_accuracy: 0.9244
# Epoch 221/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2337 - val_sparse_categorical_accuracy: 0.9244
# Epoch 222/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2426 - val_sparse_categorical_accuracy: 0.9244
# Epoch 223/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2463 - val_sparse_categorical_accuracy: 0.9244
# Epoch 224/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0109 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2385 - val_sparse_categorical_accuracy: 0.9328
# Epoch 225/2000
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.2371 - val_sparse_categorical_accuracy: 0.9328
# Epoch 226/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0082 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2360 - val_sparse_categorical_accuracy: 0.9328
# Epoch 227/2000
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0096 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2391 - val_sparse_categorical_accuracy: 0.9328
# Epoch 228/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2488 - val_sparse_categorical_accuracy: 0.9412
# Epoch 229/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0109 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2464 - val_sparse_categorical_accuracy: 0.9412
# Epoch 230/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2433 - val_sparse_categorical_accuracy: 0.9244
# Epoch 231/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0096 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2428 - val_sparse_categorical_accuracy: 0.9244
# Epoch 232/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2394 - val_sparse_categorical_accuracy: 0.9244
# Epoch 233/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0092 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2405 - val_sparse_categorical_accuracy: 0.9244
# Epoch 234/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0073 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2447 - val_sparse_categorical_accuracy: 0.9328
# Epoch 235/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2475 - val_sparse_categorical_accuracy: 0.9328
# Epoch 236/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0091 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2473 - val_sparse_categorical_accuracy: 0.9328
# Epoch 237/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0081 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2455 - val_sparse_categorical_accuracy: 0.9328
# Epoch 238/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2469 - val_sparse_categorical_accuracy: 0.9328
# Epoch 239/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0096 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2487 - val_sparse_categorical_accuracy: 0.9328
# Epoch 240/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0049 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2502 - val_sparse_categorical_accuracy: 0.9328
# Epoch 241/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0053 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2507 - val_sparse_categorical_accuracy: 0.9328
# Epoch 242/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2537 - val_sparse_categorical_accuracy: 0.9328
# Epoch 243/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0100 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2570 - val_sparse_categorical_accuracy: 0.9412
# Epoch 244/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2565 - val_sparse_categorical_accuracy: 0.9328
# Epoch 245/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2578 - val_sparse_categorical_accuracy: 0.9328
# Epoch 246/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2574 - val_sparse_categorical_accuracy: 0.9244
# Epoch 247/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0079 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2617 - val_sparse_categorical_accuracy: 0.9244
# Epoch 248/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0083 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2642 - val_sparse_categorical_accuracy: 0.9328
# Epoch 249/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2624 - val_sparse_categorical_accuracy: 0.9328
# Epoch 250/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0097 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2574 - val_sparse_categorical_accuracy: 0.9244
# Epoch 251/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0086 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2571 - val_sparse_categorical_accuracy: 0.9244
# Epoch 252/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0066 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2601 - val_sparse_categorical_accuracy: 0.9328
# Epoch 253/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0085 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2628 - val_sparse_categorical_accuracy: 0.9328
# Epoch 254/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0060 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2633 - val_sparse_categorical_accuracy: 0.9244
# Epoch 255/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2630 - val_sparse_categorical_accuracy: 0.9328
# Epoch 256/2000
# 4/4 [==============================] - 0s 119ms/step - loss: 0.0076 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2658 - val_sparse_categorical_accuracy: 0.9328
# Epoch 257/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0058 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2614 - val_sparse_categorical_accuracy: 0.9328
# Epoch 258/2000
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0073 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2552 - val_sparse_categorical_accuracy: 0.9244
# Epoch 259/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0055 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2560 - val_sparse_categorical_accuracy: 0.9244
# Epoch 260/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0056 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2573 - val_sparse_categorical_accuracy: 0.9244
# Epoch 261/2000
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2611 - val_sparse_categorical_accuracy: 0.9244
# Epoch 262/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.2653 - val_sparse_categorical_accuracy: 0.9244
# Epoch 263/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0058 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2603 - val_sparse_categorical_accuracy: 0.9244
# Epoch 264/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0068 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2588 - val_sparse_categorical_accuracy: 0.9244
# Epoch 265/2000
# ...
# Epoch 754/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 8.1501e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3931 - val_sparse_categorical_accuracy: 0.9244
# Epoch 755/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 1.9897e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3957 - val_sparse_categorical_accuracy: 0.9328
# Epoch 756/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 3.4642e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3980 - val_sparse_categorical_accuracy: 0.9328
# Epoch 757/2000
# 4/4 [==============================] - 0s 117ms/step - loss: 4.7662e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4031 - val_sparse_categorical_accuracy: 0.9328
# Epoch 758/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 5.1305e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4041 - val_sparse_categorical_accuracy: 0.9328
# Epoch 759/2000
# 4/4 [==============================] - 0s 118ms/step - loss: 3.5001e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4067 - val_sparse_categorical_accuracy: 0.9328
# Epoch 760/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 4.2231e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4099 - val_sparse_categorical_accuracy: 0.9328
# Epoch 761/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 2.3090e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4132 - val_sparse_categorical_accuracy: 0.9328
# Epoch 762/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 2.0126e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4148 - val_sparse_categorical_accuracy: 0.9328
# Epoch 763/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 3.3481e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4154 - val_sparse_categorical_accuracy: 0.9328
# Epoch 764/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 2.0260e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4153 - val_sparse_categorical_accuracy: 0.9328
# Epoch 765/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.7515e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4164 - val_sparse_categorical_accuracy: 0.9328
# Epoch 766/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4264 - val_sparse_categorical_accuracy: 0.9244
# Epoch 767/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 3.8561e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4270 - val_sparse_categorical_accuracy: 0.9244
# Epoch 768/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 6.5202e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4209 - val_sparse_categorical_accuracy: 0.9328
# Epoch 769/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 6.1826e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4121 - val_sparse_categorical_accuracy: 0.9328
# Epoch 770/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 3.2815e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4086 - val_sparse_categorical_accuracy: 0.9328
# Epoch 771/2000
# 4/4 [==============================] - 0s 115ms/step - loss: 2.2089e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4078 - val_sparse_categorical_accuracy: 0.9328
# Epoch 772/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 7.1758e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4055 - val_sparse_categorical_accuracy: 0.9412
# Epoch 773/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 3.3333e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4010 - val_sparse_categorical_accuracy: 0.9412
# Epoch 774/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.3020e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4016 - val_sparse_categorical_accuracy: 0.9412
# Epoch 775/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4110 - val_sparse_categorical_accuracy: 0.9328
# Epoch 776/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 5.5947e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4204 - val_sparse_categorical_accuracy: 0.9328
# Epoch 777/2000
# 4/4 [==============================] - 0s 120ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4289 - val_sparse_categorical_accuracy: 0.9328
# Epoch 778/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 4.1121e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4479 - val_sparse_categorical_accuracy: 0.9328
# Epoch 779/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 5.8832e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4591 - val_sparse_categorical_accuracy: 0.9328
# Epoch 780/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4478 - val_sparse_categorical_accuracy: 0.9328
# Epoch 781/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 3.8423e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4322 - val_sparse_categorical_accuracy: 0.9328
# Epoch 782/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 3.6179e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4189 - val_sparse_categorical_accuracy: 0.9328
# Epoch 783/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 5.4113e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4090 - val_sparse_categorical_accuracy: 0.9328
# Epoch 784/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 4.1343e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4077 - val_sparse_categorical_accuracy: 0.9328
# Epoch 785/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 6.7136e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4085 - val_sparse_categorical_accuracy: 0.9328
# Epoch 786/2000
# 4/4 [==============================] - 0s 118ms/step - loss: 4.6002e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4112 - val_sparse_categorical_accuracy: 0.9328
# Epoch 787/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.4460 - val_sparse_categorical_accuracy: 0.9244
# Epoch 788/2000
# 4/4 [==============================] - 0s 105ms/step - loss: 5.4281e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4751 - val_sparse_categorical_accuracy: 0.9076
# Epoch 789/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.4398 - val_sparse_categorical_accuracy: 0.9244
# Epoch 790/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 3.1627e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4055 - val_sparse_categorical_accuracy: 0.9328
# Epoch 791/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 9.0291e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3912 - val_sparse_categorical_accuracy: 0.9328
# Epoch 792/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 2.3749e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3950 - val_sparse_categorical_accuracy: 0.9328
# Epoch 793/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3921 - val_sparse_categorical_accuracy: 0.9328
# Epoch 794/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 9.3546e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3756 - val_sparse_categorical_accuracy: 0.9328
# Epoch 795/2000
# 4/4 [==============================] - 0s 121ms/step - loss: 8.5027e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3745 - val_sparse_categorical_accuracy: 0.9244
# Epoch 796/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 9.5781e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3844 - val_sparse_categorical_accuracy: 0.9328
# Epoch 797/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4017 - val_sparse_categorical_accuracy: 0.9328
# Epoch 798/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 7.0574e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4121 - val_sparse_categorical_accuracy: 0.9244
# Epoch 799/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4259 - val_sparse_categorical_accuracy: 0.9244
# Epoch 800/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4242 - val_sparse_categorical_accuracy: 0.9244
# Epoch 801/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 5.3672e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4184 - val_sparse_categorical_accuracy: 0.9328
# Epoch 802/2000
# 4/4 [==============================] - 0s 111ms/step - loss: 2.9683e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4172 - val_sparse_categorical_accuracy: 0.9328
# Epoch 803/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 8.5463e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4182 - val_sparse_categorical_accuracy: 0.9328
# Epoch 804/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 4.4021e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4152 - val_sparse_categorical_accuracy: 0.9328
# Epoch 805/2000
# 4/4 [==============================] - 0s 123ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4128 - val_sparse_categorical_accuracy: 0.9328
# Epoch 806/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 3.9401e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4051 - val_sparse_categorical_accuracy: 0.9412
# Epoch 807/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 5.9611e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4036 - val_sparse_categorical_accuracy: 0.9412
# Epoch 808/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 4.7984e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4004 - val_sparse_categorical_accuracy: 0.9412
# Epoch 809/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 7.3054e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3993 - val_sparse_categorical_accuracy: 0.9412
# Epoch 810/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 3.6170e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4003 - val_sparse_categorical_accuracy: 0.9412
# Epoch 811/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 4.3288e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4011 - val_sparse_categorical_accuracy: 0.9328
# Epoch 812/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 2.1886e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3994 - val_sparse_categorical_accuracy: 0.9412
# Epoch 813/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 3.4776e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3980 - val_sparse_categorical_accuracy: 0.9412
# Epoch 814/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 1.9549e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3971 - val_sparse_categorical_accuracy: 0.9412
# Epoch 815/2000
# 4/4 [==============================] - 0s 119ms/step - loss: 4.7720e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4030 - val_sparse_categorical_accuracy: 0.9328
# Epoch 816/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 4.7277e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4111 - val_sparse_categorical_accuracy: 0.9328
# Epoch 817/2000
# 4/4 [==============================] - 0s 120ms/step - loss: 3.0321e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4184 - val_sparse_categorical_accuracy: 0.9328
# Epoch 818/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 7.3694e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4206 - val_sparse_categorical_accuracy: 0.9328
# Epoch 819/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 4.9182e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4186 - val_sparse_categorical_accuracy: 0.9328
# Epoch 820/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 3.6294e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4204 - val_sparse_categorical_accuracy: 0.9328
# Epoch 821/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 4.1940e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4211 - val_sparse_categorical_accuracy: 0.9328
# Epoch 822/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 5.0967e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4118 - val_sparse_categorical_accuracy: 0.9328
# Epoch 823/2000
# 4/4 [==============================] - 0s 108ms/step - loss: 3.1708e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4067 - val_sparse_categorical_accuracy: 0.9328
# Epoch 824/2000
# 4/4 [==============================] - 0s 109ms/step - loss: 4.4319e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4091 - val_sparse_categorical_accuracy: 0.9328
# Epoch 825/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 8.9405e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4131 - val_sparse_categorical_accuracy: 0.9328
# Epoch 826/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 4.9756e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4163 - val_sparse_categorical_accuracy: 0.9328
# Epoch 827/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.4012 - val_sparse_categorical_accuracy: 0.9328
# Epoch 828/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3908 - val_sparse_categorical_accuracy: 0.9328
# Epoch 829/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 3.0097e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3885 - val_sparse_categorical_accuracy: 0.9412
# Epoch 830/2000
# 4/4 [==============================] - 0s 106ms/step - loss: 4.3194e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3888 - val_sparse_categorical_accuracy: 0.9412
# Epoch 831/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 6.9213e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3885 - val_sparse_categorical_accuracy: 0.9412
# Epoch 832/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.3905 - val_sparse_categorical_accuracy: 0.9412
# Epoch 833/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 4.2664e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4062 - val_sparse_categorical_accuracy: 0.9328
# Epoch 834/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 3.2853e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4240 - val_sparse_categorical_accuracy: 0.9328
# Epoch 835/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 4.0800e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4336 - val_sparse_categorical_accuracy: 0.9328
# Epoch 836/2000
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4257 - val_sparse_categorical_accuracy: 0.9328
# Epoch 837/2000
# 4/4 [==============================] - 0s 110ms/step - loss: 5.1718e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4123 - val_sparse_categorical_accuracy: 0.9328
# Epoch 838/2000
# 4/4 [==============================] - 0s 107ms/step - loss: 5.3226e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4029 - val_sparse_categorical_accuracy: 0.9328
# Epoch 839/2000
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3969 - val_sparse_categorical_accuracy: 0.9160

# %%
#testing prediction

#testing prediction
ypred1=model.predict([x_test1, x_test])

ypred=[]
#testing prediction
for i in ypred1:
    if i[0]>i[1]:
        ypred.append(0)
    else:
        ypred.append(1)
from sklearn.metrics import accuracy_score, f1_score,  jaccard_score, roc_auc_score, precision_score, recall_score
print(accuracy_score(ypred, y_test1))



print('f1_score', f1_score(ypred, y_test1))



print('jaccard_score', jaccard_score(ypred, y_test1))
print('roc_auc_score', roc_auc_score(ypred, y_test1))
print('precision_score', precision_score(ypred, y_test1))

print('recall_score', recall_score(ypred, y_test1))
# Out:
# 0.907563025210084
# f1_score 0.8842105263157894
# jaccard_score 0.7924528301886793
# roc_auc_score 0.9022887323943662
# precision_score 0.8936170212765957
# recall_score 0.875

# %%
#training prediction
xpred1=model.predict([x_train1, x_train])
xpred=[]

for i in xpred1:
    if i[0]>i[1]:
        xpred.append(0)
    else:
        xpred.append(1)
from sklearn.metrics import accuracy_score, f1_score,  jaccard_score, roc_auc_score, precision_score, recall_score
print('accuracy', accuracy_score(xpred, y_train1))



print('f1_score', f1_score(xpred, y_train1))



print('jaccard_score', jaccard_score(xpred, y_train1))
print('roc_auc_score', roc_auc_score(xpred, y_train1))
print('precision_score', precision_score(xpred, y_train1))

print('recall_score', recall_score(xpred, y_train1))
# Out:
# accuracy 1.0
# f1_score 1.0
# jaccard_score 1.0
# roc_auc_score 1.0
# precision_score 1.0
# recall_score 1.0
