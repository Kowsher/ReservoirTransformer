# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-


import tensorflow as tf
from tensorflow import keras
import numpy as np

def sparse_eye(M):
  #Generates an M x M matrix to be used as sparse identity matrix for the 
  #re-scaling of the sparse recurrent kernel in presence of non-zero leakage.
  #All the non-zero elements are set to 1
  dense_shape = (M,M)
  
  #gives the shape of a ring matrix:
  indices = np.zeros((M,2))
  for i in range(M):
      indices[i,:] = [i,i]
  values = np.ones(shape = (M,)).astype('f')

  W = (tf.sparse.reorder(tf.SparseTensor(indices = indices, values = values, dense_shape = dense_shape)))
  return W

def sparse_tensor(M,N, C = 1):
  #Generates an M x N matrix to be used as sparse (input) kernel
  #For each row only C elements are non-zero
  #(i.e., each input dimension is projected only to C neurons).
  #The non-zero elements are generated randomly from a uniform distribution in [-1,1]
  
  dense_shape = (M,N) #the shape of the dense version of the matrix
  
  indices = np.zeros((M * C,2)) #indices of non-zero elements initialization
  k = 0
  for i in range(M):
    #the indices of non-zero elements in the i-th row of the matrix
    idx =np.random.choice(N,size = C,replace = False)
    for j in range(C):
      indices[k,:] = [i,idx[j]]
      k = k + 1
  values = 2*(2*np.random.rand(M*C).astype('f')-1)
  W = (tf.sparse.reorder(tf.SparseTensor(indices = indices, values = values, dense_shape = dense_shape)))
  return W


def sparse_recurrent_tensor(M, C = 1):
  #Generates an M x M matrix to be used as sparse recurrent kernel
  #For each column only C elements are non-zero
  #(i.e., each recurrent neuron take sinput from C other recurrent neurons).
  #The non-zero elements are generated randomly from a uniform distribution in [-1,1]
  
  dense_shape = (M,M) #the shape of the dense version of the matrix
  
  indices = np.zeros((M * C,2)) #indices of non-zero elements initialization
  k = 0
  for i in range(M):
    #the indices of non-zero elements in the i-th column of the matrix
    idx =np.random.choice(M,size = C,replace = False)
    for j in range(C):
      indices[k,:] = [idx[j],i]
      k = k + 1
  values = 2*(2*np.random.rand(M*C).astype('f')-1)
  W = (tf.sparse.reorder(tf.SparseTensor(indices = indices, values = values, dense_shape = dense_shape)))
  return W


class ReservoirCell(keras.layers.Layer):
    #Implementation of a shallow reservoir to be used as cell of a Recurrent Neural Network
    #The implementation is parametrized by:
    # units - the number of recurrent neurons in the reservoir
    # input_scaling - the max abs value of a weight in the input-reservoir connections
    #                 note that whis value also scales the unitary input bias 
    # spectral_radius - the max abs eigenvalue of the recurrent weight matrix
    # leaky - the leaking rate constant of the reservoir
    # connectivity_input - number of outgoing connections from each input unit to the reservoir
    # connectivity_recurrent - number of incoming recurrent connections for each reservoir unit
    
    def __init__(self, units, 
                 input_scaling = 1., spectral_radius =0.99, leaky = 1, 
                 connectivity_input = 10, connectivity_recurrent = 10,
                 **kwargs):
        
        self.units = units
        self.state_size = units
        self.input_scaling = input_scaling
        self.spectral_radius = spectral_radius
        self.leaky = leaky
        self.connectivity_input = connectivity_input
        self.connectivity_recurrent = connectivity_recurrent
        super().__init__(**kwargs)
        
    def build(self, input_shape):
        
        #build the input weight matrix
        self.kernel = sparse_tensor(input_shape[-1], self.units, self.connectivity_input) * self.input_scaling
        
        
        #build the recurrent weight matrix
        W = sparse_recurrent_tensor(self.units, C = self.connectivity_recurrent)

        #re-scale the weight matrix to control the effective spectral radius of the linearized system
        if (self.leaky ==1):
            #if no leakage then rescale the W matrix
            # compute the spectral radius of the randomly initialized matrix
            e,_ = tf.linalg.eig(tf.sparse.to_dense(W))
            rho = max(abs(e))
            #rescale the matrix to the desired spectral radius
            W = W * (self.spectral_radius / rho)
            self.recurrent_kernel = W
        else:
            I = sparse_eye(self.units)
            W2 = tf.sparse.add(I * (1-self.leaky), W * self.leaky)
            e,_ = tf.linalg.eig(tf.sparse.to_dense(W2))
            rho = max(abs(e))
            W2 = W2 * (self.spectral_radius / rho)
            self.recurrent_kernel =  tf.sparse.add(W2, I * (self.leaky - 1)) * (1/self.leaky)               
        
        self.bias = tf.random.uniform(shape = (self.units,), minval = -1, maxval = 1) * self.input_scaling
        
        self.built = True


    def call(self, inputs, states):
        #computes the output of the cell givne the input and previous state
        prev_output = states[0]

        input_part = tf.sparse.sparse_dense_matmul(inputs, self.kernel)
        state_part = tf.sparse.sparse_dense_matmul(prev_output, self.recurrent_kernel)
        output = prev_output * (1-self.leaky) + tf.nn.tanh(input_part+ self.bias+ state_part) * self.leaky
        
        return output, [output]
    
    
class SimpleDeepReservoirLayer(keras.layers.Layer):
    #A layer structure implementing the functionalities of a Deep Reservoir.
    #The implementation realizes a number of stacked RNN layers using 
    #the ReservoirCell above as core cell.
    #In this simple implementation, all the reservoir levels share the same values
    #of all the hyper-parameters (i.e., the same number of recurrent neurons, spectral radius, etc. )
    #The layer is parametrized by the following:
    # concat - if True the returned state is given by the cocnatenation of all the states in the reservoir levels 
    # units - the number of recurrent units used in the neural network; 
    #         if concat == True this is the total number of units
    #         if concat == False this is the number of units for each reservoir level
    # input_scaling - the scaling coefficient of the first reserovir level
    # inter_scaling - the scaling coefficient of all the other reservoir levels (> 1)
    # spectral_radius - the spectral radius of all the reservoir levels
    # leaky - the leakage coefficient of all the reservoir levels
    # connectivity_input - input connectivity coefficient of the input weight matrix
    # connectivity_inter - input connectivity coefficient of all the inter-levels weight matrices
    # connectivity_recurrent - recurrent connectivity coefficient of all the recurrent weight matrices
    # return_sequences - if True, the state is returned for each time step, otherwise only for the last time step
    
    def __init__(self, units = 100, layers = 1, concat = False,
                 input_scaling = 1, inter_scaling = 1,
                 spectral_radius = 0.99, leaky = 1,
                 connectivity_recurrent = 10, 
                 connectivity_input = 10, 
                 connectivity_inter = 10,
                 return_sequences = False,
                 **kwargs):
        
        super().__init__(**kwargs)
        self.layers = layers
        self.units = units
        

        #in case in which all the reservoir layers are concatenated
        #each level contains units/layers neurons
        #this is done to keep the number of state variables projected to the next layer fixed
        #i.e., the number of trainable parameters does not depend on concat
        if concat:
            units = np.int(units/layers)
        
        
        input_scaling_others = inter_scaling #input scaling for the higher layers
        connectivity_input_1 = connectivity_input  #input connectivity coefficient for the 1st layer
        connectivity_input_others = connectivity_inter #inter-layer connectivity coefficient

        
        #creates a list of reservoirs
        #the first: 
        
        self.reservoir = [
        keras.layers.RNN(ReservoirCell(units = units,
                             input_scaling = input_scaling,
                             spectral_radius = spectral_radius,
                             leaky = leaky,
                             connectivity_input = connectivity_input_1,
                             connectivity_recurrent = connectivity_recurrent),
                             return_sequences=True,return_state=True
                             )]
        #all the others:
        for _ in range(layers-1):
            self.reservoir.append(keras.layers.RNN(ReservoirCell(units = units,
                                                             input_scaling = input_scaling_others,
                                                             spectral_radius = spectral_radius,
                                                             leaky = leaky,
                                                             connectivity_input = connectivity_input_others,
                                                             connectivity_recurrent = connectivity_recurrent),
                                                   return_sequences = True,return_state = True))

        
        self.concat = concat
        
        self.return_sequences = return_sequences
        
        
    def call(self,inputs):
        #compute the output of the deep reservoir
        
        #I = keras.layers.InputLayer(input_shape = self.batch_input_shape)
        
        X = inputs #I(inputs) #external input
        states = [] #list of all the states in all the layers 
        states_last = [] #list of the states in all the layers for the last time step
        layer_states = None
            
        for reservoir_index in range(len(self.reservoir)):
            reservoir_layer = self.reservoir[reservoir_index]
            if reservoir_index > 0:
                X = layer_states
            [layer_states, layer_states_last] = reservoir_layer(X)
            states.append(layer_states)
            states_last.append(layer_states_last)
        
        #concatenate the states if needed
        if self.concat:
            if self.return_sequences:
                #in this case return the concatenation of the states in all the layers
                #at each time step
                return keras.layers.Concatenate()(states)
            else:
                #in this case concatenate the states of all the states in all the layers
                #for the last time step
                return keras.layers.Concatenate()(states_last)            
        else:
            #in this case only the last reservoir layer is used to feed the next layer in the net
            if self.return_sequences:
                #all the time steps for the last layer
                return states[-1]
            else:
                #the last time step for the last layer
                return states_last[-1]    



#The SimpleDeepReservoirLayer can be used to build more complex models.
#As an example, in the following code we create a SimpleDeepESNClassifier 
#that can be trained to classify arbitrarily long input time-series.
#The architecture contains a SimpleDeepReservoirLayer followed by a Dense layer for classification

class SimpleDeepESNClassifier(keras.Model):
    def __init__(self, num_classes, units = 100, layers = 5, 
                 concat = True,
                 spectral_radius = 0.99, leaky = 1,
                 input_scaling = 1, inter_scaling = 1,
                 connectivity_recurrent = 10, 
                 connectivity_input = 10, 
                 connectivity_inter = 10,
                 return_sequences = False,
                 **kwargs):
        super().__init__(**kwargs)
        

        
        self.num_classes = num_classes
        #a Masking layer is used before the SimpleDeepReservoirLayer to deal with
        #possibly arbitrarily long input time-series
        self.masking = tf.keras.layers.Masking()
        self.hidden = SimpleDeepReservoirLayer(units = units, layers = layers,
                                         concat = concat,
                                         spectral_radius = spectral_radius, leaky = leaky,
                                         input_scaling = input_scaling, 
                                         inter_scaling = inter_scaling,
                                         connectivity_recurrent = connectivity_recurrent, 
                                         connectivity_input = connectivity_input, 
                                         connectivity_inter = connectivity_inter,
                                         return_sequences = return_sequences)
        if (num_classes>2):
            self.output_ = tf.keras.layers.Dense(num_classes,
                                                activation = 'softmax')
        else:
            self.output_ = tf.keras.layers.Dense(1,
                                                activation = 'sigmoid')
            
    
    def call(self, inputs):
        m = self.masking(inputs)
        h = self.hidden(m)
        y = self.output_(h)
        return y

# %%
import pandas as pd

df = pd.read_csv('/content/univ-length-over10.short-col-names.csv')

#df=df.drop(columns = ['date'])
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
#df = imputer.fit_transform(df)

from sklearn.preprocessing import LabelEncoder
le1= LabelEncoder()
le2= LabelEncoder()
le3= LabelEncoder()
df['predWillFollowIncreaseCapacity']=le1.fit_transform(df['predWillFollowIncreaseCapacity'])
df['Ft-ULen-Over10-didFollowIncreaseCapacity']=le2.fit_transform(df['Ft-ULen-Over10-didFollowIncreaseCapacity'])

'''
df=df.dropna()
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le1 = LabelEncoder()
le2 = LabelEncoder()
'''


#df['icon']= le.fit_transform(df['icon'])

y = df['Ft-ULen-Over10-didFollowIncreaseCapacity'].values
df=df.drop(columns = ['Ft-ULen-Over10-didFollowIncreaseCapacity'])
X = df.values

X=X[1:]
y=y[1:]

for i in range(len(y)):
    if y[i]==2:
        y[i]=1

# %%
y=y.reshape(-1, 1)


import numpy as np
X=np.concatenate((X[1:], y[0:-1]), axis=1)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X= sc.fit_transform(X)

from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1 = train_test_split(X, y[1:], test_size=0.2, shuffle=False, random_state=42)

# %%
x_train1 = x_train1.reshape((x_train1.shape[0], x_train1.shape[1], 1))
x_test1 = x_test1.reshape((x_test1.shape[0], x_test1.shape[1], 1))

# %%
x_train1.shape
# Out:
# (473, 20, 1)

# %%
# univariate bidirectional lstm example
from numpy import array
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Conv1D, MaxPooling1D,Flatten, Attention, Dropout, Add, concatenate
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Bidirectional
import tensorflow as tf
from keras.regularizers import L1L2

# %%
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM, Conv1D, MaxPooling1D, GRU
from keras.layers import Dense, Dropout
from keras.layers import Bidirectional
import tensorflow as tf
# define model
inputs = tensorflow.keras.Input((20, 1))

x = SimpleDeepESNClassifier(2, 50, 5)(inputs)



x = Dense(128, activation="relu")(x)


x = Dense(28, activation="relu")(x)

outputs = Dense(2, activation="softmax")(x)
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:172: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 20, 1)]           0
#
#  simple_deep_esn_classifier_  (None, 1)                51
#  1 (SimpleDeepESNClassifier)
#
#  dense_5 (Dense)             (None, 128)               256
#
#  dense_6 (Dense)             (None, 28)                3612
#
#  dense_7 (Dense)             (None, 2)                 58
#
# =================================================================
# Total params: 3,977
# Trainable params: 3,977
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    metrics=["sparse_categorical_accuracy"],
)

# %%
callbacks = [keras.callbacks.EarlyStopping(patience=60, restore_best_weights=True)]

history=model.fit(
    x_train1,
    y_train1,
    validation_data=(x_test1, y_test1),
    epochs=200,
    batch_size=128,
    callbacks=callbacks,
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 155ms/step - loss: 0.6666 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6624 - val_sparse_categorical_accuracy: 0.6050
# Epoch 2/200
# 4/4 [==============================] - 0s 122ms/step - loss: 0.6653 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6607 - val_sparse_categorical_accuracy: 0.6050
# Epoch 3/200
# 4/4 [==============================] - 1s 164ms/step - loss: 0.6658 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6599 - val_sparse_categorical_accuracy: 0.6050
# Epoch 4/200
# 4/4 [==============================] - 0s 104ms/step - loss: 0.6650 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6593 - val_sparse_categorical_accuracy: 0.6050
# Epoch 5/200
# 4/4 [==============================] - 0s 93ms/step - loss: 0.6643 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6601 - val_sparse_categorical_accuracy: 0.6050
# Epoch 6/200
# 4/4 [==============================] - 1s 153ms/step - loss: 0.6651 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6589 - val_sparse_categorical_accuracy: 0.6050
# Epoch 7/200
# 4/4 [==============================] - 1s 165ms/step - loss: 0.6639 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6586 - val_sparse_categorical_accuracy: 0.6050
# Epoch 8/200
# 4/4 [==============================] - 1s 207ms/step - loss: 0.6634 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6584 - val_sparse_categorical_accuracy: 0.6050
# Epoch 9/200
# 4/4 [==============================] - 0s 102ms/step - loss: 0.6650 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6582 - val_sparse_categorical_accuracy: 0.6050
# Epoch 10/200
# 4/4 [==============================] - 0s 103ms/step - loss: 0.6692 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6620 - val_sparse_categorical_accuracy: 0.6050
# Epoch 11/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.6639 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6581 - val_sparse_categorical_accuracy: 0.6050
# Epoch 12/200
# 4/4 [==============================] - 1s 155ms/step - loss: 0.6623 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6597 - val_sparse_categorical_accuracy: 0.6050
# Epoch 13/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.6661 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6586 - val_sparse_categorical_accuracy: 0.6050
# Epoch 14/200
# 4/4 [==============================] - 0s 87ms/step - loss: 0.6630 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6605 - val_sparse_categorical_accuracy: 0.6050
# Epoch 15/200
# 4/4 [==============================] - 1s 164ms/step - loss: 0.6640 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6604 - val_sparse_categorical_accuracy: 0.6050
# Epoch 16/200
# 4/4 [==============================] - 1s 157ms/step - loss: 0.6622 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6584 - val_sparse_categorical_accuracy: 0.6050
# Epoch 17/200
# 4/4 [==============================] - 0s 126ms/step - loss: 0.6670 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6601 - val_sparse_categorical_accuracy: 0.6050
# Epoch 18/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.6658 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6605 - val_sparse_categorical_accuracy: 0.6050
# Epoch 19/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.6625 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6603 - val_sparse_categorical_accuracy: 0.6050
# Epoch 20/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.6623 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6592 - val_sparse_categorical_accuracy: 0.6050
# Epoch 21/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.6611 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6593 - val_sparse_categorical_accuracy: 0.6050
# Epoch 22/200
# 4/4 [==============================] - 0s 93ms/step - loss: 0.6608 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6593 - val_sparse_categorical_accuracy: 0.6050
# Epoch 23/200
# 4/4 [==============================] - 0s 124ms/step - loss: 0.6611 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6594 - val_sparse_categorical_accuracy: 0.6050
# Epoch 24/200
# 4/4 [==============================] - 0s 128ms/step - loss: 0.6600 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6600 - val_sparse_categorical_accuracy: 0.6050
# Epoch 25/200
# 4/4 [==============================] - 0s 122ms/step - loss: 0.6599 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6598 - val_sparse_categorical_accuracy: 0.6050
# Epoch 26/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6592 - sparse_categorical_accuracy: 0.6004 - val_loss: 0.6601 - val_sparse_categorical_accuracy: 0.6050
# Epoch 27/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.6592 - sparse_categorical_accuracy: 0.6004 - val_loss: 0.6604 - val_sparse_categorical_accuracy: 0.6134
# Epoch 28/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6585 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6608 - val_sparse_categorical_accuracy: 0.6134
# Epoch 29/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6584 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6612 - val_sparse_categorical_accuracy: 0.6050
# Epoch 30/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6583 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6614 - val_sparse_categorical_accuracy: 0.6134
# Epoch 31/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6576 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6620 - val_sparse_categorical_accuracy: 0.6134
# Epoch 32/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6577 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6628 - val_sparse_categorical_accuracy: 0.6050
# Epoch 33/200
# 4/4 [==============================] - 0s 68ms/step - loss: 0.6570 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.6050
# Epoch 34/200
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6567 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6637 - val_sparse_categorical_accuracy: 0.5966
# Epoch 35/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6576 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6644 - val_sparse_categorical_accuracy: 0.5882
# Epoch 36/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6565 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6648 - val_sparse_categorical_accuracy: 0.6134
# Epoch 37/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6566 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6655 - val_sparse_categorical_accuracy: 0.6134
# Epoch 38/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6575 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6667 - val_sparse_categorical_accuracy: 0.6134
# Epoch 39/200
# 4/4 [==============================] - 0s 67ms/step - loss: 0.6565 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6670 - val_sparse_categorical_accuracy: 0.5966
# Epoch 40/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6569 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6674 - val_sparse_categorical_accuracy: 0.6050
# Epoch 41/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6564 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6679 - val_sparse_categorical_accuracy: 0.6050
# Epoch 42/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6560 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6702 - val_sparse_categorical_accuracy: 0.6050
# Epoch 43/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6571 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6694 - val_sparse_categorical_accuracy: 0.6050
# Epoch 44/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6578 - sparse_categorical_accuracy: 0.5983 - val_loss: 0.6703 - val_sparse_categorical_accuracy: 0.5714
# Epoch 45/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6585 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6692 - val_sparse_categorical_accuracy: 0.6050
# Epoch 46/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6549 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6698 - val_sparse_categorical_accuracy: 0.6050
# Epoch 47/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6568 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.6050
# Epoch 48/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6549 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6694 - val_sparse_categorical_accuracy: 0.6050
# Epoch 49/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6546 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6695 - val_sparse_categorical_accuracy: 0.6050
# Epoch 50/200
# 4/4 [==============================] - 0s 76ms/step - loss: 0.6557 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6698 - val_sparse_categorical_accuracy: 0.6050
# Epoch 51/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6549 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6703 - val_sparse_categorical_accuracy: 0.6050
# Epoch 52/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6545 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6703 - val_sparse_categorical_accuracy: 0.6050
# Epoch 53/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6543 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6702 - val_sparse_categorical_accuracy: 0.6050
# Epoch 54/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6562 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6702 - val_sparse_categorical_accuracy: 0.6050
# Epoch 55/200
# 4/4 [==============================] - 0s 71ms/step - loss: 0.6545 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6697 - val_sparse_categorical_accuracy: 0.5882
# Epoch 56/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6548 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.6695 - val_sparse_categorical_accuracy: 0.6050
# Epoch 57/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6539 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6704 - val_sparse_categorical_accuracy: 0.6050
# Epoch 58/200
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6553 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6725 - val_sparse_categorical_accuracy: 0.6134
# Epoch 59/200
# 4/4 [==============================] - 0s 69ms/step - loss: 0.6547 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6700 - val_sparse_categorical_accuracy: 0.6050
# Epoch 60/200
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6548 - sparse_categorical_accuracy: 0.6004 - val_loss: 0.6700 - val_sparse_categorical_accuracy: 0.5714
# Epoch 61/200
# 4/4 [==============================] - 0s 68ms/step - loss: 0.6550 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6703 - val_sparse_categorical_accuracy: 0.6050
# Epoch 62/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6534 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.6050
# Epoch 63/200
# 4/4 [==============================] - 0s 71ms/step - loss: 0.6536 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.6050
# Epoch 64/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6535 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.6050
# Epoch 65/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6543 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.6050
# Epoch 66/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6533 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.6050
# Epoch 67/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6557 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6712 - val_sparse_categorical_accuracy: 0.6050
# Epoch 68/200
# 4/4 [==============================] - 0s 71ms/step - loss: 0.6529 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6703 - val_sparse_categorical_accuracy: 0.5714
# Epoch 69/200
# 4/4 [==============================] - 0s 70ms/step - loss: 0.6539 - sparse_categorical_accuracy: 0.5962 - val_loss: 0.6704 - val_sparse_categorical_accuracy: 0.5966
# Epoch 70/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6527 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.6050
# Epoch 71/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6530 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6710 - val_sparse_categorical_accuracy: 0.6050
# Epoch 72/200
# 4/4 [==============================] - 0s 73ms/step - loss: 0.6531 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6719 - val_sparse_categorical_accuracy: 0.6050
# Epoch 73/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6526 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.6134
# Epoch 74/200
# 4/4 [==============================] - 0s 67ms/step - loss: 0.6523 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6704 - val_sparse_categorical_accuracy: 0.6050
# Epoch 75/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6523 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.6711 - val_sparse_categorical_accuracy: 0.5966
# Epoch 76/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6523 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6707 - val_sparse_categorical_accuracy: 0.6134
# Epoch 77/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6522 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.6717 - val_sparse_categorical_accuracy: 0.6134
# Epoch 78/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6520 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6728 - val_sparse_categorical_accuracy: 0.6050
# Epoch 79/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.6529 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6728 - val_sparse_categorical_accuracy: 0.6050
# Epoch 80/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6549 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6706 - val_sparse_categorical_accuracy: 0.5714
# Epoch 81/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6527 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6697 - val_sparse_categorical_accuracy: 0.6050
# Epoch 82/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6512 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6728 - val_sparse_categorical_accuracy: 0.5966
# Epoch 83/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6522 - sparse_categorical_accuracy: 0.6216 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.5966
# Epoch 84/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6508 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6703 - val_sparse_categorical_accuracy: 0.5882
# Epoch 85/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6506 - sparse_categorical_accuracy: 0.6004 - val_loss: 0.6702 - val_sparse_categorical_accuracy: 0.5714
# Epoch 86/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6513 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.5798
# Epoch 87/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6519 - sparse_categorical_accuracy: 0.5941 - val_loss: 0.6723 - val_sparse_categorical_accuracy: 0.6134
# Epoch 88/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6502 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.5966
# Epoch 89/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6514 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.6700 - val_sparse_categorical_accuracy: 0.5798
# Epoch 90/200
# 4/4 [==============================] - 0s 53ms/step - loss: 0.6512 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.6697 - val_sparse_categorical_accuracy: 0.5966
# Epoch 91/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6501 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6741 - val_sparse_categorical_accuracy: 0.5966
# Epoch 92/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6514 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.6050
# Epoch 93/200
# 4/4 [==============================] - 0s 68ms/step - loss: 0.6495 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6703 - val_sparse_categorical_accuracy: 0.5882
# Epoch 94/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6516 - sparse_categorical_accuracy: 0.6025 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.5798
# Epoch 95/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6494 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6716 - val_sparse_categorical_accuracy: 0.5966
# Epoch 96/200
# 4/4 [==============================] - 0s 70ms/step - loss: 0.6501 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6747 - val_sparse_categorical_accuracy: 0.5966
# Epoch 97/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6500 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6701 - val_sparse_categorical_accuracy: 0.5966
# Epoch 98/200
# 4/4 [==============================] - 0s 65ms/step - loss: 0.6493 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.6702 - val_sparse_categorical_accuracy: 0.5882
# Epoch 99/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6494 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6712 - val_sparse_categorical_accuracy: 0.6050
# Epoch 100/200
# 4/4 [==============================] - 0s 70ms/step - loss: 0.6489 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6715 - val_sparse_categorical_accuracy: 0.5966
# Epoch 101/200
# 4/4 [==============================] - 0s 68ms/step - loss: 0.6490 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6726 - val_sparse_categorical_accuracy: 0.6050
# Epoch 102/200
# 4/4 [==============================] - 0s 71ms/step - loss: 0.6492 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.5882
# Epoch 103/200
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6487 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6714 - val_sparse_categorical_accuracy: 0.5882
# Epoch 104/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.6486 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.5798
# Epoch 105/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6479 - sparse_categorical_accuracy: 0.6068 - val_loss: 0.6723 - val_sparse_categorical_accuracy: 0.5966
# Epoch 106/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6490 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6732 - val_sparse_categorical_accuracy: 0.5966
# Epoch 107/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6478 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6711 - val_sparse_categorical_accuracy: 0.5798
# Epoch 108/200
# 4/4 [==============================] - 0s 67ms/step - loss: 0.6495 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6707 - val_sparse_categorical_accuracy: 0.5882
# Epoch 109/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6477 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6720 - val_sparse_categorical_accuracy: 0.5882
# Epoch 110/200
# 4/4 [==============================] - 0s 65ms/step - loss: 0.6492 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6726 - val_sparse_categorical_accuracy: 0.5882
# Epoch 111/200
# 4/4 [==============================] - 0s 67ms/step - loss: 0.6476 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.6710 - val_sparse_categorical_accuracy: 0.5798
# Epoch 112/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6508 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6708 - val_sparse_categorical_accuracy: 0.5798
# Epoch 113/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6478 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.6712 - val_sparse_categorical_accuracy: 0.5966
# Epoch 114/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6472 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6726 - val_sparse_categorical_accuracy: 0.5966
# Epoch 115/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6480 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6713 - val_sparse_categorical_accuracy: 0.5882
# Epoch 116/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6475 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6704 - val_sparse_categorical_accuracy: 0.5798
# Epoch 117/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6470 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6704 - val_sparse_categorical_accuracy: 0.5630
# Epoch 118/200
# 4/4 [==============================] - 0s 67ms/step - loss: 0.6479 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6707 - val_sparse_categorical_accuracy: 0.5798
# Epoch 119/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6464 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6740 - val_sparse_categorical_accuracy: 0.5966
# Epoch 120/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6488 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6714 - val_sparse_categorical_accuracy: 0.5966
# Epoch 121/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6474 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6707 - val_sparse_categorical_accuracy: 0.5714
# Epoch 122/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6493 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6702 - val_sparse_categorical_accuracy: 0.5798
# Epoch 123/200
# 4/4 [==============================] - 0s 67ms/step - loss: 0.6465 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6719 - val_sparse_categorical_accuracy: 0.5882
# Epoch 124/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6489 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6730 - val_sparse_categorical_accuracy: 0.5966
# Epoch 125/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6471 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6709 - val_sparse_categorical_accuracy: 0.5798
# Epoch 126/200
# 4/4 [==============================] - 0s 65ms/step - loss: 0.6476 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6701 - val_sparse_categorical_accuracy: 0.5882
# Epoch 127/200
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6463 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6718 - val_sparse_categorical_accuracy: 0.5966
# Epoch 128/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6505 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6721 - val_sparse_categorical_accuracy: 0.5882
# Epoch 129/200
# 4/4 [==============================] - 0s 70ms/step - loss: 0.6438 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6712 - val_sparse_categorical_accuracy: 0.5714
# Epoch 130/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6505 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6699 - val_sparse_categorical_accuracy: 0.5714
# Epoch 131/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6468 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6727 - val_sparse_categorical_accuracy: 0.5882
# Epoch 132/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6477 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6725 - val_sparse_categorical_accuracy: 0.5882
# Epoch 133/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6459 - sparse_categorical_accuracy: 0.6216 - val_loss: 0.6703 - val_sparse_categorical_accuracy: 0.5714
# Epoch 134/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6482 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6720 - val_sparse_categorical_accuracy: 0.5630
# Epoch 135/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6491 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.6736 - val_sparse_categorical_accuracy: 0.5882
# Epoch 136/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6454 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6738 - val_sparse_categorical_accuracy: 0.5966
# Epoch 137/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6458 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6723 - val_sparse_categorical_accuracy: 0.5882
# Epoch 138/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6460 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6730 - val_sparse_categorical_accuracy: 0.5882
# Epoch 139/200
# 4/4 [==============================] - 0s 69ms/step - loss: 0.6464 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6751 - val_sparse_categorical_accuracy: 0.5882
# Epoch 140/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6468 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6707 - val_sparse_categorical_accuracy: 0.5714
# Epoch 141/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6453 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6710 - val_sparse_categorical_accuracy: 0.5714
# Epoch 142/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6448 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6730 - val_sparse_categorical_accuracy: 0.5882
# Epoch 143/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6465 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6746 - val_sparse_categorical_accuracy: 0.5882
# Epoch 144/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6441 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6719 - val_sparse_categorical_accuracy: 0.5714
# Epoch 145/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6465 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6723 - val_sparse_categorical_accuracy: 0.5546
# Epoch 146/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6449 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.6744 - val_sparse_categorical_accuracy: 0.5882
# Epoch 147/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.6450 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6797 - val_sparse_categorical_accuracy: 0.5882
# Epoch 148/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6451 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6747 - val_sparse_categorical_accuracy: 0.5714
# Epoch 149/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6464 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6728 - val_sparse_categorical_accuracy: 0.5462
# Epoch 150/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6465 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6731 - val_sparse_categorical_accuracy: 0.5630
# Epoch 151/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6473 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6811 - val_sparse_categorical_accuracy: 0.5882
# Epoch 152/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6459 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6733 - val_sparse_categorical_accuracy: 0.5714
# Epoch 153/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6443 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6723 - val_sparse_categorical_accuracy: 0.5546
# Epoch 154/200
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6454 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6725 - val_sparse_categorical_accuracy: 0.5714
# Epoch 155/200
# 4/4 [==============================] - 0s 68ms/step - loss: 0.6439 - sparse_categorical_accuracy: 0.6300 - val_loss: 0.6745 - val_sparse_categorical_accuracy: 0.5882
# Epoch 156/200
# 4/4 [==============================] - 0s 65ms/step - loss: 0.6436 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6735 - val_sparse_categorical_accuracy: 0.5798
# Epoch 157/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6438 - sparse_categorical_accuracy: 0.6258 - val_loss: 0.6724 - val_sparse_categorical_accuracy: 0.5798
# Epoch 158/200
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6442 - sparse_categorical_accuracy: 0.6216 - val_loss: 0.6712 - val_sparse_categorical_accuracy: 0.5630
# Epoch 159/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6444 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6721 - val_sparse_categorical_accuracy: 0.5714
# Epoch 160/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6452 - sparse_categorical_accuracy: 0.6216 - val_loss: 0.6771 - val_sparse_categorical_accuracy: 0.5882
# Epoch 161/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6439 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6728 - val_sparse_categorical_accuracy: 0.5798
# Epoch 162/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6446 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.6739 - val_sparse_categorical_accuracy: 0.5546
# Epoch 163/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6440 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6742 - val_sparse_categorical_accuracy: 0.5714
# Epoch 164/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6440 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6807 - val_sparse_categorical_accuracy: 0.5882
# Epoch 165/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6440 - sparse_categorical_accuracy: 0.6258 - val_loss: 0.6740 - val_sparse_categorical_accuracy: 0.5714
# Epoch 166/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6437 - sparse_categorical_accuracy: 0.6258 - val_loss: 0.6720 - val_sparse_categorical_accuracy: 0.5630
# Epoch 167/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6438 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6720 - val_sparse_categorical_accuracy: 0.5714
# Epoch 168/200
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6438 - sparse_categorical_accuracy: 0.6258 - val_loss: 0.6754 - val_sparse_categorical_accuracy: 0.5882
# Epoch 169/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6427 - sparse_categorical_accuracy: 0.6279 - val_loss: 0.6746 - val_sparse_categorical_accuracy: 0.5714
# Epoch 170/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6421 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6745 - val_sparse_categorical_accuracy: 0.5462
# Epoch 171/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6435 - sparse_categorical_accuracy: 0.6216 - val_loss: 0.6761 - val_sparse_categorical_accuracy: 0.5630
# Epoch 172/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6422 - sparse_categorical_accuracy: 0.6258 - val_loss: 0.6755 - val_sparse_categorical_accuracy: 0.5714
# Epoch 173/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6421 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6743 - val_sparse_categorical_accuracy: 0.5714
# Epoch 174/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6424 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6731 - val_sparse_categorical_accuracy: 0.5630
# Epoch 175/200
# 4/4 [==============================] - 0s 57ms/step - loss: 0.6418 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6749 - val_sparse_categorical_accuracy: 0.5714
# Epoch 176/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6419 - sparse_categorical_accuracy: 0.6342 - val_loss: 0.6761 - val_sparse_categorical_accuracy: 0.5714
# Epoch 177/200
# 4/4 [==============================] - 0s 68ms/step - loss: 0.6420 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6755 - val_sparse_categorical_accuracy: 0.5630
# Epoch 178/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6421 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6762 - val_sparse_categorical_accuracy: 0.5714
# Epoch 179/200
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6423 - sparse_categorical_accuracy: 0.6279 - val_loss: 0.6730 - val_sparse_categorical_accuracy: 0.5630
# Epoch 180/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6418 - sparse_categorical_accuracy: 0.6216 - val_loss: 0.6743 - val_sparse_categorical_accuracy: 0.5798
# Epoch 181/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6413 - sparse_categorical_accuracy: 0.6279 - val_loss: 0.6759 - val_sparse_categorical_accuracy: 0.5798
# Epoch 182/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6412 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6743 - val_sparse_categorical_accuracy: 0.5798
# Epoch 183/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6411 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6750 - val_sparse_categorical_accuracy: 0.5882
# Epoch 184/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6408 - sparse_categorical_accuracy: 0.6300 - val_loss: 0.6753 - val_sparse_categorical_accuracy: 0.5714
# Epoch 185/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6408 - sparse_categorical_accuracy: 0.6258 - val_loss: 0.6722 - val_sparse_categorical_accuracy: 0.5882
# Epoch 186/200
# 4/4 [==============================] - 0s 71ms/step - loss: 0.6408 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.6726 - val_sparse_categorical_accuracy: 0.5882
# Epoch 187/200
# 4/4 [==============================] - 0s 66ms/step - loss: 0.6414 - sparse_categorical_accuracy: 0.6300 - val_loss: 0.6754 - val_sparse_categorical_accuracy: 0.5798
# Epoch 188/200
# 4/4 [==============================] - 0s 65ms/step - loss: 0.6414 - sparse_categorical_accuracy: 0.6300 - val_loss: 0.6718 - val_sparse_categorical_accuracy: 0.5882
# Epoch 189/200
# 4/4 [==============================] - 0s 67ms/step - loss: 0.6409 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6730 - val_sparse_categorical_accuracy: 0.5798
# Epoch 190/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6403 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6785 - val_sparse_categorical_accuracy: 0.5714
# Epoch 191/200
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6419 - sparse_categorical_accuracy: 0.6300 - val_loss: 0.6790 - val_sparse_categorical_accuracy: 0.5714
# Epoch 192/200
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6406 - sparse_categorical_accuracy: 0.6279 - val_loss: 0.6758 - val_sparse_categorical_accuracy: 0.5714
# Epoch 193/200
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6414 - sparse_categorical_accuracy: 0.6216 - val_loss: 0.6755 - val_sparse_categorical_accuracy: 0.5714
# Epoch 194/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6402 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6754 - val_sparse_categorical_accuracy: 0.5798
# Epoch 195/200
# 4/4 [==============================] - 0s 65ms/step - loss: 0.6417 - sparse_categorical_accuracy: 0.6195 - val_loss: 0.6733 - val_sparse_categorical_accuracy: 0.5714
# Epoch 196/200
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6404 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.6767 - val_sparse_categorical_accuracy: 0.5630
# Epoch 197/200
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6397 - sparse_categorical_accuracy: 0.6152 - val_loss: 0.6776 - val_sparse_categorical_accuracy: 0.5798
# Epoch 198/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6396 - sparse_categorical_accuracy: 0.6279 - val_loss: 0.6780 - val_sparse_categorical_accuracy: 0.5798
# Epoch 199/200
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6396 - sparse_categorical_accuracy: 0.6279 - val_loss: 0.6780 - val_sparse_categorical_accuracy: 0.5798
# Epoch 200/200
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6390 - sparse_categorical_accuracy: 0.6279 - val_loss: 0.6758 - val_sparse_categorical_accuracy: 0.5714

# %%
#testing prediction

#testing prediction
ypred1=model.predict([x_test1])

ypred=[]
#testing prediction
for i in ypred1:
    if i[0]>i[1]:
        ypred.append(0)
    else:
        ypred.append(1)
from sklearn.metrics import accuracy_score, f1_score,  jaccard_score, roc_auc_score, precision_score, recall_score
print(accuracy_score(ypred, y_test1))



print('f1_score', f1_score(ypred, y_test1))



print('jaccard_score', jaccard_score(ypred, y_test1))
print('roc_auc_score', roc_auc_score(ypred, y_test1))
print('precision_score', precision_score(ypred, y_test1))

print('recall_score', recall_score(ypred, y_test1))
# Out:
# 0.5714285714285714
# f1_score 0.3013698630136986
# jaccard_score 0.1774193548387097
# roc_auc_score 0.5179900744416874
# precision_score 0.23404255319148937
# recall_score 0.4230769230769231

# %%
#training prediction
xpred1=model.predict([x_train1])
xpred=[]

for i in xpred1:
    if i[0]>i[1]:
        xpred.append(0)
    else:
        xpred.append(1)
from sklearn.metrics import accuracy_score, f1_score,  jaccard_score, roc_auc_score, precision_score, recall_score
print('accuracy', accuracy_score(xpred, y_train1))



print('f1_score', f1_score(xpred, y_train1))



print('jaccard_score', jaccard_score(xpred, y_train1))
print('roc_auc_score', roc_auc_score(xpred, y_train1))
print('precision_score', precision_score(xpred, y_train1))

print('recall_score', recall_score(xpred, y_train1))
# Out:
# accuracy 0.627906976744186
# f1_score 0.4013605442176871
# jaccard_score 0.251063829787234
# roc_auc_score 0.6025525679913629
# precision_score 0.31382978723404253
# recall_score 0.5566037735849056
